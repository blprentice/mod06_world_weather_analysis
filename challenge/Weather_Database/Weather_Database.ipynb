# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | maiduguri
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | storforshei
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | walvis bay
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | urubicha
# Processing Record 12 of Set 1 | pital
# Processing Record 13 of Set 1 | harper
# Processing Record 14 of Set 1 | margate
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | namibe
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | niquelandia
# Processing Record 21 of Set 1 | addis abeba
# Processing Record 22 of Set 1 | coquimbo
# Processing Record 23 of Set 1 | coihaique
# Processing Record 24 of Set 1 | durania
# Processing Record 25 of Set 1 | xai-xai
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | los llanos de aridane
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | caninde
# Processing Record 30 of Set 1 | ancud
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | bandarbeyla
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | tiruchchendur
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | pizarro
# Processing Record 38 of Set 1 | shahreza
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | luderitz
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 1 | sisimiut
# Processing Record 45 of Set 1 | eyl
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 1 | klaksvik
# Processing Record 49 of Set 1 | hammerfest
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | olot
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | shache
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | paamiut
# Processing Record 7 of Set 2 | kruisfontein
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | necochea
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | loughrea
# Processing Record 12 of Set 2 | verkhnedneprovskiy
# Processing Record 13 of Set 2 | ambilobe
# Processing Record 14 of Set 2 | morros
# Processing Record 15 of Set 2 | marsa matruh
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | monrovia
# Processing Record 18 of Set 2 | salisbury
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | beyneu
# Processing Record 21 of Set 2 | avallon
# Processing Record 22 of Set 2 | leshukonskoye
# Processing Record 23 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 2 | valparaiso
# Processing Record 25 of Set 2 | angoche
# Processing Record 26 of Set 2 | adrar
# Processing Record 27 of Set 2 | youkounkoun
# Processing Record 28 of Set 2 | oranjestad
# Processing Record 29 of Set 2 | lahij
# Processing Record 30 of Set 2 | kudahuvadhoo
# Processing Record 31 of Set 2 | berlevag
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | diourbel
# Processing Record 34 of Set 2 | maniitsoq
# Processing Record 35 of Set 2 | shakiso
# Processing Record 36 of Set 2 | chalisgaon
# Processing Record 37 of Set 2 | ginda
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | oranjemund
# Processing Record 40 of Set 2 | ankazobe
# Processing Record 41 of Set 2 | magole
# Processing Record 42 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 2 | abu dhabi
# Processing Record 44 of Set 2 | imbituba
# Processing Record 45 of Set 2 | fasa
# Processing Record 46 of Set 2 | souillac
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | nalut
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | gurupi
# Processing Record 1 of Set 3 | yefira
# City not found. Skipping...
# Processing Record 2 of Set 3 | vawkavysk
# Processing Record 3 of Set 3 | galeras
# Processing Record 4 of Set 3 | tonota
# Processing Record 5 of Set 3 | parati
# Processing Record 6 of Set 3 | malakal
# Processing Record 7 of Set 3 | koslan
# Processing Record 8 of Set 3 | evansville
# Processing Record 9 of Set 3 | mangan
# Processing Record 10 of Set 3 | itarema
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | the valley
# Processing Record 13 of Set 3 | busselton
# Processing Record 14 of Set 3 | zheleznodorozhnyy
# Processing Record 15 of Set 3 | sao filipe
# Processing Record 16 of Set 3 | saint-paul
# Processing Record 17 of Set 3 | grindavik
# Processing Record 18 of Set 3 | haradok
# Processing Record 19 of Set 3 | salalah
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | jalu
# Processing Record 22 of Set 3 | alpena
# Processing Record 23 of Set 3 | zharkent
# Processing Record 24 of Set 3 | nouakchott
# Processing Record 25 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | jumla
# Processing Record 30 of Set 3 | karaton
# Processing Record 31 of Set 3 | ostersund
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | mercedes
# Processing Record 34 of Set 3 | la asuncion
# Processing Record 35 of Set 3 | henties bay
# Processing Record 36 of Set 3 | sorland
# Processing Record 37 of Set 3 | touros
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | pocosol
# Processing Record 40 of Set 3 | umm kaddadah
# Processing Record 41 of Set 3 | okandja
# City not found. Skipping...
# Processing Record 42 of Set 3 | orange walk
# Processing Record 43 of Set 3 | kollumerland
# City not found. Skipping...
# Processing Record 44 of Set 3 | nybro
# Processing Record 45 of Set 3 | cockburn town
# Processing Record 46 of Set 3 | felanitx
# Processing Record 47 of Set 3 | olafsvik
# Processing Record 48 of Set 3 | ornskoldsvik
# Processing Record 49 of Set 3 | sinjah
# City not found. Skipping...
# Processing Record 50 of Set 3 | aquiraz
# Processing Record 1 of Set 4 | chabahar
# Processing Record 2 of Set 4 | thinadhoo
# Processing Record 3 of Set 4 | bara
# Processing Record 4 of Set 4 | dujuma
# City not found. Skipping...
# Processing Record 5 of Set 4 | kotturu
# Processing Record 6 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 4 | luba
# Processing Record 8 of Set 4 | buarcos
# Processing Record 9 of Set 4 | mar del plata
# Processing Record 10 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 4 | charyshskoye
# Processing Record 12 of Set 4 | barranca
# Processing Record 13 of Set 4 | forio
# Processing Record 14 of Set 4 | san salvador
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | vieques
# Processing Record 17 of Set 4 | calabozo
# Processing Record 18 of Set 4 | sinnamary
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | kulhudhuffushi
# Processing Record 21 of Set 4 | ciudad bolivar
# Processing Record 22 of Set 4 | sokoto
# Processing Record 23 of Set 4 | jipijapa
# Processing Record 24 of Set 4 | caravelas
# Processing Record 25 of Set 4 | omboue
# Processing Record 26 of Set 4 | pervomayskoye
# Processing Record 27 of Set 4 | lebu
# Processing Record 28 of Set 4 | novoagansk
# Processing Record 29 of Set 4 | mulchen
# Processing Record 30 of Set 4 | san cristobal
# Processing Record 31 of Set 4 | vila franca do campo
# Processing Record 32 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 4 | lodja
# Processing Record 35 of Set 4 | nokaneng
# Processing Record 36 of Set 4 | santa margherita ligure
# Processing Record 37 of Set 4 | reda
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | general roca
# Processing Record 40 of Set 4 | abu samrah
# Processing Record 41 of Set 4 | trairi
# Processing Record 42 of Set 4 | sekovici
# Processing Record 43 of Set 4 | muros
# Processing Record 44 of Set 4 | waterloo
# Processing Record 45 of Set 4 | kosh-agach
# Processing Record 46 of Set 4 | tessalit
# Processing Record 47 of Set 4 | thyboron
# Processing Record 48 of Set 4 | sabha
# Processing Record 49 of Set 4 | kalmunai
# Processing Record 50 of Set 4 | raudeberg
# Processing Record 1 of Set 5 | tabas
# Processing Record 2 of Set 5 | havoysund
# Processing Record 3 of Set 5 | kondinskoye
# Processing Record 4 of Set 5 | abomey
# Processing Record 5 of Set 5 | korla
# Processing Record 6 of Set 5 | boa vista
# Processing Record 7 of Set 5 | tallahassee
# Processing Record 8 of Set 5 | semirom
# Processing Record 9 of Set 5 | pangody
# Processing Record 10 of Set 5 | ludwigsfelde
# Processing Record 11 of Set 5 | bilma
# Processing Record 12 of Set 5 | jos
# Processing Record 13 of Set 5 | gornopravdinsk
# Processing Record 14 of Set 5 | quatre cocos
# Processing Record 15 of Set 5 | esfahan
# Processing Record 16 of Set 5 | kalmar
# Processing Record 17 of Set 5 | stokmarknes
# Processing Record 18 of Set 5 | san carlos de bariloche
# Processing Record 19 of Set 5 | ajdabiya
# Processing Record 20 of Set 5 | ghogha
# Processing Record 21 of Set 5 | hobyo
# Processing Record 22 of Set 5 | sovetskiy
# Processing Record 23 of Set 5 | novo aripuana
# Processing Record 24 of Set 5 | saint-pierre
# Processing Record 25 of Set 5 | ostrovnoy
# Processing Record 26 of Set 5 | kot kapura
# Processing Record 27 of Set 5 | coruripe
# Processing Record 28 of Set 5 | benguela
# Processing Record 29 of Set 5 | alba
# Processing Record 30 of Set 5 | lepe
# Processing Record 31 of Set 5 | grand gaube
# Processing Record 32 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 5 | sao joao da barra
# Processing Record 34 of Set 5 | liverpool
# Processing Record 35 of Set 5 | babati
# Processing Record 36 of Set 5 | faya
# Processing Record 37 of Set 5 | blagoyevo
# Processing Record 38 of Set 5 | jibuti
# Processing Record 39 of Set 5 | varhaug
# Processing Record 40 of Set 5 | ekuvukeni
# Processing Record 41 of Set 5 | gamba
# Processing Record 42 of Set 5 | khakhea
# Processing Record 43 of Set 5 | porto belo
# Processing Record 44 of Set 5 | boldumsaz
# Processing Record 45 of Set 5 | cascais
# Processing Record 46 of Set 5 | husavik
# Processing Record 47 of Set 5 | saint-pacome
# City not found. Skipping...
# Processing Record 48 of Set 5 | plettenberg bay
# Processing Record 49 of Set 5 | obala
# Processing Record 50 of Set 5 | rawson
# Processing Record 1 of Set 6 | zemio
# Processing Record 2 of Set 6 | niono
# Processing Record 3 of Set 6 | laukaa
# Processing Record 4 of Set 6 | dulyapino
# Processing Record 5 of Set 6 | sur
# Processing Record 6 of Set 6 | cabedelo
# Processing Record 7 of Set 6 | smestad
# Processing Record 8 of Set 6 | santa rosa
# Processing Record 9 of Set 6 | nadym
# Processing Record 10 of Set 6 | bathsheba
# Processing Record 11 of Set 6 | longyearbyen
# Processing Record 12 of Set 6 | krasnoarmeysk
# Processing Record 13 of Set 6 | toktogul
# Processing Record 14 of Set 6 | almeirim
# Processing Record 15 of Set 6 | seydi
# Processing Record 16 of Set 6 | visby
# Processing Record 17 of Set 6 | urengoy
# Processing Record 18 of Set 6 | salinopolis
# Processing Record 19 of Set 6 | cap-aux-meules
# Processing Record 20 of Set 6 | marabba
# Processing Record 21 of Set 6 | bodden town
# Processing Record 22 of Set 6 | sokoni
# Processing Record 23 of Set 6 | bayan
# Processing Record 24 of Set 6 | arsenion
# Processing Record 25 of Set 6 | tubingen
# City not found. Skipping...
# Processing Record 26 of Set 6 | sao felix do xingu
# Processing Record 27 of Set 6 | ghorawal
# Processing Record 28 of Set 6 | nantucket
# Processing Record 29 of Set 6 | bonthe
# Processing Record 30 of Set 6 | matara
# Processing Record 31 of Set 6 | amot
# Processing Record 32 of Set 6 | richards bay
# Processing Record 33 of Set 6 | minas
# Processing Record 34 of Set 6 | gouyave
# Processing Record 35 of Set 6 | bartica
# Processing Record 36 of Set 6 | yei
# Processing Record 37 of Set 6 | gerash
# Processing Record 38 of Set 6 | krasnaya zarya
# Processing Record 39 of Set 6 | garowe
# Processing Record 40 of Set 6 | gwadar
# Processing Record 41 of Set 6 | llanes
# Processing Record 42 of Set 6 | yenagoa
# Processing Record 43 of Set 6 | garliava
# Processing Record 44 of Set 6 | wote
# Processing Record 45 of Set 6 | puerto madryn
# Processing Record 46 of Set 6 | valisoara
# Processing Record 47 of Set 6 | ouadda
# Processing Record 48 of Set 6 | guiratinga
# Processing Record 49 of Set 6 | galle
# Processing Record 50 of Set 6 | praia da vitoria
# Processing Record 1 of Set 7 | bakchar
# Processing Record 2 of Set 7 | bud
# Processing Record 3 of Set 7 | dolores
# Processing Record 4 of Set 7 | tuskegee
# Processing Record 5 of Set 7 | lucapa
# Processing Record 6 of Set 7 | darnetal
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | pangnirtung
# Processing Record 9 of Set 7 | nuuk
# Processing Record 10 of Set 7 | sangueya
# Processing Record 11 of Set 7 | bardiyah
# Processing Record 12 of Set 7 | soubre
# Processing Record 13 of Set 7 | barinas
# Processing Record 14 of Set 7 | kanpur
# Processing Record 15 of Set 7 | bari
# Processing Record 16 of Set 7 | monroe
# Processing Record 17 of Set 7 | tanout
# Processing Record 18 of Set 7 | krasnoselkup
# Processing Record 19 of Set 7 | camacha
# Processing Record 20 of Set 7 | roald
# Processing Record 21 of Set 7 | aktau
# Processing Record 22 of Set 7 | swidnik
# Processing Record 23 of Set 7 | blonie
# Processing Record 24 of Set 7 | bengkulu
# Processing Record 25 of Set 7 | posse
# Processing Record 26 of Set 7 | morant bay
# Processing Record 27 of Set 7 | langres
# Processing Record 28 of Set 7 | sainte-suzanne
# Processing Record 29 of Set 7 | gwembe
# Processing Record 30 of Set 7 | mabaruma
# Processing Record 31 of Set 7 | padang
# Processing Record 32 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 7 | siparia
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | esik
# Processing Record 36 of Set 7 | banikoara
# Processing Record 37 of Set 7 | muriae
# Processing Record 38 of Set 7 | saint anthony
# Processing Record 39 of Set 7 | staraya russa
# Processing Record 40 of Set 7 | puerto el triunfo
# Processing Record 41 of Set 7 | vylkove
# Processing Record 42 of Set 7 | sokolo
# Processing Record 43 of Set 7 | upington
# Processing Record 44 of Set 7 | velikodvorskiy
# Processing Record 45 of Set 7 | khadyzhensk
# Processing Record 46 of Set 7 | pershotravneve
# Processing Record 47 of Set 7 | kunda
# Processing Record 48 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 49 of Set 7 | velsk
# Processing Record 50 of Set 7 | campos belos
# Processing Record 1 of Set 8 | puerto cabezas
# Processing Record 2 of Set 8 | marsh harbour
# Processing Record 3 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 8 | cayenne
# Processing Record 5 of Set 8 | maridi
# Processing Record 6 of Set 8 | rio grande
# Processing Record 7 of Set 8 | halifax
# Processing Record 8 of Set 8 | fulton
# Processing Record 9 of Set 8 | vardo
# Processing Record 10 of Set 8 | kothapet
# Processing Record 11 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 8 | jacksonville
# Processing Record 14 of Set 8 | safaga
# Processing Record 15 of Set 8 | ghatsila
# Processing Record 16 of Set 8 | kapuskasing
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | koundara
# Processing Record 19 of Set 8 | west bay
# Processing Record 20 of Set 8 | victoria falls
# Processing Record 21 of Set 8 | herne bay
# Processing Record 22 of Set 8 | kadoma
# Processing Record 23 of Set 8 | taoudenni
# Processing Record 24 of Set 8 | torrevieja
# Processing Record 25 of Set 8 | barcelos
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | tazovskiy
# Processing Record 28 of Set 8 | jardim
# Processing Record 29 of Set 8 | praia
# Processing Record 30 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 31 of Set 8 | geraldton
# Processing Record 32 of Set 8 | synya
# Processing Record 33 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 8 | masuguru
# Processing Record 35 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 37 of Set 8 | ajaccio
# Processing Record 38 of Set 8 | dolgorukovo
# Processing Record 39 of Set 8 | mosquera
# Processing Record 40 of Set 8 | lima
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | hambantota
# Processing Record 43 of Set 8 | laje
# Processing Record 44 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 8 | briancon
# Processing Record 46 of Set 8 | puerto montt
# Processing Record 47 of Set 8 | luanda
# Processing Record 48 of Set 8 | shuyskoye
# Processing Record 49 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 8 | yanam
# Processing Record 1 of Set 9 | atbasar
# Processing Record 2 of Set 9 | male
# Processing Record 3 of Set 9 | longonjo
# Processing Record 4 of Set 9 | kattivakkam
# Processing Record 5 of Set 9 | bar harbor
# Processing Record 6 of Set 9 | santa fe
# Processing Record 7 of Set 9 | damietta
# Processing Record 8 of Set 9 | muisne
# Processing Record 9 of Set 9 | laguna
# Processing Record 10 of Set 9 | wake forest
# Processing Record 11 of Set 9 | japura
# Processing Record 12 of Set 9 | nador
# Processing Record 13 of Set 9 | patos
# Processing Record 14 of Set 9 | awbari
# Processing Record 15 of Set 9 | jodar
# Processing Record 16 of Set 9 | manbij
# Processing Record 17 of Set 9 | tabou
# Processing Record 18 of Set 9 | castro
# Processing Record 19 of Set 9 | bereda
# Processing Record 20 of Set 9 | mayumba
# Processing Record 21 of Set 9 | mogadishu
# Processing Record 22 of Set 9 | farafangana
# Processing Record 23 of Set 9 | allada
# Processing Record 24 of Set 9 | pacaembu
# Processing Record 25 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 9 | sembe
# Processing Record 27 of Set 9 | riyadh
# Processing Record 28 of Set 9 | kilakarai
# Processing Record 29 of Set 9 | sumbe
# Processing Record 30 of Set 9 | clinton
# Processing Record 31 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 32 of Set 9 | amudat
# Processing Record 33 of Set 9 | kalabo
# Processing Record 34 of Set 9 | tromso
# Processing Record 35 of Set 9 | mattru
# Processing Record 36 of Set 9 | kovdor
# Processing Record 37 of Set 9 | mahon
# Processing Record 38 of Set 9 | moose factory
# Processing Record 39 of Set 9 | stornoway
# Processing Record 40 of Set 9 | ibra
# Processing Record 41 of Set 9 | varkaus
# Processing Record 42 of Set 9 | skegness
# Processing Record 43 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 9 | cap malheureux
# Processing Record 45 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 46 of Set 9 | basyanovskiy
# City not found. Skipping...
# Processing Record 47 of Set 9 | diffa
# Processing Record 48 of Set 9 | livingstone
# Processing Record 49 of Set 9 | qasigiannguit
# Processing Record 50 of Set 9 | mecca
# Processing Record 1 of Set 10 | buraydah
# Processing Record 2 of Set 10 | saint-joseph
# Processing Record 3 of Set 10 | toumodi
# Processing Record 4 of Set 10 | brae
# Processing Record 5 of Set 10 | dudinka
# Processing Record 6 of Set 10 | mustasaari
# Processing Record 7 of Set 10 | channel-port aux basques
# Processing Record 8 of Set 10 | rabo de peixe
# Processing Record 9 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 10 of Set 10 | zverinogolovskoye
# Processing Record 11 of Set 10 | moussoro
# Processing Record 12 of Set 10 | akdepe
# Processing Record 13 of Set 10 | chingirlau
# Processing Record 14 of Set 10 | vestmanna
# Processing Record 15 of Set 10 | chigorodo
# Processing Record 16 of Set 10 | sambava
# Processing Record 17 of Set 10 | aswan
# Processing Record 18 of Set 10 | ler
# Processing Record 19 of Set 10 | manga
# Processing Record 20 of Set 10 | umm lajj
# Processing Record 21 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 10 | taybad
# Processing Record 23 of Set 10 | sekoma
# Processing Record 24 of Set 10 | bossangoa
# Processing Record 25 of Set 10 | uyemskiy
# Processing Record 26 of Set 10 | gat
# Processing Record 27 of Set 10 | forchheim
# Processing Record 28 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 29 of Set 10 | ormara
# Processing Record 30 of Set 10 | port-gentil
# Processing Record 31 of Set 10 | waqqas
# Processing Record 32 of Set 10 | la palma
# Processing Record 33 of Set 10 | marawi
# Processing Record 34 of Set 10 | san ramon
# Processing Record 35 of Set 10 | burica
# City not found. Skipping...
# Processing Record 36 of Set 10 | arumbavur
# Processing Record 37 of Set 10 | vasai
# Processing Record 38 of Set 10 | mozarlandia
# Processing Record 39 of Set 10 | guarapari
# Processing Record 40 of Set 10 | batavia
# Processing Record 41 of Set 10 | punta de bombon
# Processing Record 42 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 10 | kirkcudbright
# Processing Record 44 of Set 10 | caluquembe
# Processing Record 45 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | bandar-e lengeh
# Processing Record 47 of Set 10 | tchaourou
# Processing Record 48 of Set 10 | clarence town
# Processing Record 49 of Set 10 | gaoual
# Processing Record 50 of Set 10 | filiatra
# Processing Record 1 of Set 11 | talnakh
# Processing Record 2 of Set 11 | iberia
# Processing Record 3 of Set 11 | osuna
# Processing Record 4 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 5 of Set 11 | alta floresta
# Processing Record 6 of Set 11 | manyana
# Processing Record 7 of Set 11 | kaduy
# Processing Record 8 of Set 11 | den helder
# Processing Record 9 of Set 11 | la romana
# Processing Record 10 of Set 11 | tombouctou
# Processing Record 11 of Set 11 | arlit
# Processing Record 12 of Set 11 | villa carlos paz
# Processing Record 13 of Set 11 | la libertad
# Processing Record 14 of Set 11 | santa cruz
# Processing Record 15 of Set 11 | bonfim
# Processing Record 16 of Set 11 | monkey bay
# Processing Record 17 of Set 11 | doha
# Processing Record 18 of Set 11 | orgita
# Processing Record 19 of Set 11 | hamilton
# Processing Record 20 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 11 | bella vista
# Processing Record 22 of Set 11 | alcantara
# Processing Record 23 of Set 11 | diu
# Processing Record 24 of Set 11 | herre
# Processing Record 25 of Set 11 | tabulbah
# City not found. Skipping...
# Processing Record 26 of Set 11 | numan
# Processing Record 27 of Set 11 | kavaratti
# Processing Record 28 of Set 11 | vila velha
# Processing Record 29 of Set 11 | ilebo
# Processing Record 30 of Set 11 | malinyi
# Processing Record 31 of Set 11 | karwar
# Processing Record 32 of Set 11 | soyo
# Processing Record 33 of Set 11 | reo
# Processing Record 34 of Set 11 | bayji
# Processing Record 35 of Set 11 | mehamn
# Processing Record 36 of Set 11 | nyakabindi
# Processing Record 37 of Set 11 | buchanan
# Processing Record 38 of Set 11 | rudnichnyy
# Processing Record 39 of Set 11 | oistins
# Processing Record 40 of Set 11 | carutapera
# Processing Record 41 of Set 11 | les cayes
# Processing Record 42 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 43 of Set 11 | montepuez
# Processing Record 44 of Set 11 | sao jose da coroa grande
# Processing Record 45 of Set 11 | limulunga
# Processing Record 46 of Set 11 | lasa
# Processing Record 47 of Set 11 | malanje
# Processing Record 48 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 49 of Set 11 | dakar
# Processing Record 50 of Set 11 | awjilah
# Processing Record 1 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 2 of Set 12 | farah
# Processing Record 3 of Set 12 | durban
# Processing Record 4 of Set 12 | floro
# Processing Record 5 of Set 12 | cap-chat
# Processing Record 6 of Set 12 | saint-augustin
# Processing Record 7 of Set 12 | carnarvon
# Processing Record 8 of Set 12 | igarka
# Processing Record 9 of Set 12 | key largo
# Processing Record 10 of Set 12 | kulotino
# Processing Record 11 of Set 12 | belmopan
# Processing Record 12 of Set 12 | courtalam
# City not found. Skipping...
# Processing Record 13 of Set 12 | rieti
# Processing Record 14 of Set 12 | conceicao do rio verde
# Processing Record 15 of Set 12 | catamarca
# Processing Record 16 of Set 12 | olavarria
# Processing Record 17 of Set 12 | albanel
# Processing Record 18 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 12 | nusaybin
# Processing Record 20 of Set 12 | taltal
# Processing Record 21 of Set 12 | koszalin
# Processing Record 22 of Set 12 | micheweni
# Processing Record 23 of Set 12 | atakpame
# Processing Record 24 of Set 12 | puerto suarez
# Processing Record 25 of Set 12 | aksarka
# Processing Record 26 of Set 12 | maragogi
# Processing Record 27 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 12 | chapais
# Processing Record 29 of Set 12 | bagotville
# Processing Record 30 of Set 12 | pangani
# Processing Record 31 of Set 12 | elizabeth city
# Processing Record 32 of Set 12 | baghdad
# Processing Record 33 of Set 12 | tarusa
# Processing Record 34 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 35 of Set 12 | zanjan
# Processing Record 36 of Set 12 | ust-kishert
# Processing Record 37 of Set 12 | kristiinankaupunki
# Processing Record 38 of Set 12 | piura
# Processing Record 39 of Set 12 | lavumisa
# Processing Record 40 of Set 12 | alot
# Processing Record 41 of Set 12 | ubinskoye
# Processing Record 42 of Set 12 | hofn
# Processing Record 43 of Set 12 | matay
# Processing Record 44 of Set 12 | ponta pora
# Processing Record 45 of Set 12 | veliki preslav
# Processing Record 46 of Set 12 | comodoro rivadavia
# Processing Record 47 of Set 12 | tarancon
# Processing Record 48 of Set 12 | arkhipo-osipovka
# Processing Record 49 of Set 12 | antofagasta
# Processing Record 50 of Set 12 | tashtyp
# Processing Record 1 of Set 13 | bonavista
# Processing Record 2 of Set 13 | khudaganj
# Processing Record 3 of Set 13 | mastic beach
# Processing Record 4 of Set 13 | sechura
# Processing Record 5 of Set 13 | mtambile
# Processing Record 6 of Set 13 | kamenka
# Processing Record 7 of Set 13 | brunswick
# Processing Record 8 of Set 13 | huarmey
# Processing Record 9 of Set 13 | inirida
# Processing Record 10 of Set 13 | tarauaca
# Processing Record 11 of Set 13 | great yarmouth
# Processing Record 12 of Set 13 | ugoofaaru
# Processing Record 13 of Set 13 | nioro
# Processing Record 14 of Set 13 | constitucion
# Processing Record 15 of Set 13 | moyale
# Processing Record 16 of Set 13 | igrim
# Processing Record 17 of Set 13 | antalaha
# Processing Record 18 of Set 13 | dobryanka
# Processing Record 19 of Set 13 | aden
# Processing Record 20 of Set 13 | warrington
# Processing Record 21 of Set 13 | grajau
# Processing Record 22 of Set 13 | sovetsk
# Processing Record 23 of Set 13 | labrea
# Processing Record 24 of Set 13 | skibbereen
# Processing Record 25 of Set 13 | snezhnogorsk
# Processing Record 26 of Set 13 | shelburne
# Processing Record 27 of Set 13 | sawakin
# Processing Record 28 of Set 13 | chipiona
# Processing Record 29 of Set 13 | sotik
# Processing Record 30 of Set 13 | castres
# Processing Record 31 of Set 13 | cabo rojo
# Processing Record 32 of Set 13 | srimushnam
# Processing Record 33 of Set 13 | belmonte
# Processing Record 34 of Set 13 | killybegs
# Processing Record 35 of Set 13 | oriximina
# Processing Record 36 of Set 13 | kerouane
# Processing Record 37 of Set 13 | lamu
# Processing Record 38 of Set 13 | humaita
# Processing Record 39 of Set 13 | manama
# Processing Record 40 of Set 13 | talalayivka
# Processing Record 41 of Set 13 | pavagada
# Processing Record 42 of Set 13 | acari
# Processing Record 43 of Set 13 | piterka
# Processing Record 44 of Set 13 | sioux lookout
# Processing Record 45 of Set 13 | cayambe
# Processing Record 46 of Set 13 | mauganj
# Processing Record 47 of Set 13 | thunder bay
# Processing Record 48 of Set 13 | campos gerais
# Processing Record 49 of Set 13 | viloco
# Processing Record 50 of Set 13 | khorixas
# Processing Record 1 of Set 14 | galich
# Processing Record 2 of Set 14 | mikkeli
# Processing Record 3 of Set 14 | jalingo
# Processing Record 4 of Set 14 | altay
# Processing Record 5 of Set 14 | troitsko-pechorsk
# Processing Record 6 of Set 14 | vicuna
# Processing Record 7 of Set 14 | barreirinha
# Processing Record 8 of Set 14 | eidsvag
# Processing Record 9 of Set 14 | springbok
# Processing Record 10 of Set 14 | knysna
# Processing Record 11 of Set 14 | nova ushytsya
# Processing Record 12 of Set 14 | dunmore town
# Processing Record 13 of Set 14 | turtas
# Processing Record 14 of Set 14 | guliston
# Processing Record 15 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 14 | lukovetskiy
# Processing Record 17 of Set 14 | beloha
# Processing Record 18 of Set 14 | tamandare
# Processing Record 19 of Set 14 | alto araguaia
# Processing Record 20 of Set 14 | eufaula
# Processing Record 21 of Set 14 | gambela
# Processing Record 22 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 23 of Set 14 | cocal
# Processing Record 24 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 25 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 26 of Set 14 | tocopilla
# Processing Record 27 of Set 14 | kasungu
# Processing Record 28 of Set 14 | pudozh
# Processing Record 29 of Set 14 | iquique
# Processing Record 30 of Set 14 | dharmadam
# Processing Record 31 of Set 14 | mwinilunga
# Processing Record 32 of Set 14 | road town
# Processing Record 33 of Set 14 | nkhotakota
# Processing Record 34 of Set 14 | nicoya
# Processing Record 35 of Set 14 | nargana
# Processing Record 36 of Set 14 | haselunne
# Processing Record 37 of Set 14 | logrono
# Processing Record 38 of Set 14 | boende
# Processing Record 39 of Set 14 | goba
# Processing Record 40 of Set 14 | viransehir
# Processing Record 41 of Set 14 | port-cartier
# Processing Record 42 of Set 14 | camana
# Processing Record 43 of Set 14 | oussouye
# Processing Record 44 of Set 14 | san lawrenz
# Processing Record 45 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 46 of Set 14 | duma
# Processing Record 47 of Set 14 | chandur bazar
# Processing Record 48 of Set 14 | dawlatabad
# Processing Record 49 of Set 14 | arrifes
# Processing Record 50 of Set 14 | sakakah
# Processing Record 1 of Set 15 | traverse city
# Processing Record 2 of Set 15 | ous
# Processing Record 3 of Set 15 | remedios
# Processing Record 4 of Set 15 | volterra
# Processing Record 5 of Set 15 | meulaboh
# Processing Record 6 of Set 15 | oum hadjer
# Processing Record 7 of Set 15 | finnsnes
# Processing Record 8 of Set 15 | mitsamiouli
# Processing Record 9 of Set 15 | phalaborwa
# Processing Record 10 of Set 15 | kpandu
# Processing Record 11 of Set 15 | sergeyevka
# Processing Record 12 of Set 15 | arthur
# Processing Record 13 of Set 15 | rudbar
# Processing Record 14 of Set 15 | sinazongwe
# Processing Record 15 of Set 15 | muhos
# Processing Record 16 of Set 15 | porto santo
# Processing Record 17 of Set 15 | santa maria
# Processing Record 18 of Set 15 | nunspeet
# Processing Record 19 of Set 15 | moissala
# Processing Record 20 of Set 15 | chiredzi
# Processing Record 21 of Set 15 | methoni
# Processing Record 22 of Set 15 | haverhill
# Processing Record 23 of Set 15 | isiro
# Processing Record 24 of Set 15 | cibitoke
# Processing Record 25 of Set 15 | iracoubo
# Processing Record 26 of Set 15 | mizpe ramon
# City not found. Skipping...
# Processing Record 27 of Set 15 | pustoshka
# Processing Record 28 of Set 15 | chake chake
# Processing Record 29 of Set 15 | bell ville
# Processing Record 30 of Set 15 | andenes
# Processing Record 31 of Set 15 | romitan
# Processing Record 32 of Set 15 | oeiras do para
# Processing Record 33 of Set 15 | mantua
# Processing Record 34 of Set 15 | gaffney
# Processing Record 35 of Set 15 | phuthaditjhaba
# Processing Record 36 of Set 15 | rebrikha
# Processing Record 37 of Set 15 | bull savanna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -77.5902, 'lat': 17.8868},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 80.08,
#   'feels_like': 81.48,
#   'temp_min': 80.08,
#   'temp_max': 80.08,
#   'pressure': 1014,
#   'humidity': 56,
#   'sea_level': 1014,
#   'grnd_level': 987},
#  'visibility': 10000,
#  'wind': {'speed': 9.82, 'deg': 196, 'gust': 9.78},
#  'clouds': {'all': 93},
#  'dt': 1678387663,
#  'sys': {'country': 'JM', 'sunrise': 1678361006, 'sunset': 1678403922},
#  'timezone': -18000,
#  'id': 3491161,
#  'name': 'Bull Savanna',
#  'cod': 200}

# %%
# Print the length of the city_data list to verify how many cities you have
#len(city_data)
print(len(city_data))
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Maiduguri      NG  11.8464  13.1603     77.05        25          41
# 1       Bredasdorp      ZA -34.5322  20.0403     61.32        80           0
# 2           Dikson      RU  73.5069  80.5464    -18.62        97          95
# 3      Storforshei      NO  66.4043  14.5233     -6.02        77          98
# 4   Ribeira Grande      PT  38.5167 -28.7000     61.77        94          80
# 5     Ponta Do Sol      PT  32.6667 -17.1000     67.71        89          80
# 6            Lagoa      PT  39.0500 -27.9833     59.90        88          87
# 7  Arraial Do Cabo      BR -22.9661 -42.0278     75.88        92         100
# 8       Walvis Bay      NA -22.9575  14.5053     62.10        94           0
# 9         Hermanus      ZA -34.4187  19.2345     65.80        77           1
#
#    Wind Speed       Description
# 0        7.87  scattered clouds
# 1        5.95         clear sky
# 2       12.73   overcast clouds
# 3        6.91   overcast clouds
# 4       18.99     broken clouds
# 5        5.64     broken clouds
# 6       20.42   overcast clouds
# 7       17.94   overcast clouds
# 8        6.91         clear sky
# 9       15.21         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Maiduguri      NG  11.8464  13.1603     77.05        25          41
# 1       Bredasdorp      ZA -34.5322  20.0403     61.32        80           0
# 2           Dikson      RU  73.5069  80.5464    -18.62        97          95
# 3      Storforshei      NO  66.4043  14.5233     -6.02        77          98
# 4   Ribeira Grande      PT  38.5167 -28.7000     61.77        94          80
# 5     Ponta Do Sol      PT  32.6667 -17.1000     67.71        89          80
# 6            Lagoa      PT  39.0500 -27.9833     59.90        88          87
# 7  Arraial Do Cabo      BR -22.9661 -42.0278     75.88        92         100
# 8       Walvis Bay      NA -22.9575  14.5053     62.10        94           0
# 9         Hermanus      ZA -34.4187  19.2345     65.80        77           1
#
#    Wind Speed       Description
# 0        7.87  scattered clouds
# 1        5.95         clear sky
# 2       12.73   overcast clouds
# 3        6.91   overcast clouds
# 4       18.99     broken clouds
# 5        5.64     broken clouds
# 6       20.42   overcast clouds
# 7       17.94   overcast clouds
# 8        6.91         clear sky
# 9       15.21         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
