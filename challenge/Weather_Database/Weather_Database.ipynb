# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 733

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | westport
# Processing Record 3 of Set 1 | nantucket
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | galle
# Processing Record 10 of Set 1 | saint-augustin
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | tabou
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | tazovskiy
# Processing Record 15 of Set 1 | codrington
# Processing Record 16 of Set 1 | oriximina
# Processing Record 17 of Set 1 | urupes
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | quelimane
# Processing Record 20 of Set 1 | taoudenni
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | sachin
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | ambilobe
# Processing Record 26 of Set 1 | henties bay
# Processing Record 27 of Set 1 | turukhansk
# Processing Record 28 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 1 | marzuq
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | aksarka
# Processing Record 32 of Set 1 | takoradi
# Processing Record 33 of Set 1 | skibbereen
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | krasnoselkup
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | altagracia de orituco
# Processing Record 40 of Set 1 | hofn
# Processing Record 41 of Set 1 | margate
# Processing Record 42 of Set 1 | gorodishche
# Processing Record 43 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 1 | safaga
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | sao joao da barra
# Processing Record 47 of Set 1 | mahajanga
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | mangan
# Processing Record 50 of Set 1 | rudbar
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | sao filipe
# Processing Record 3 of Set 2 | hamilton
# Processing Record 4 of Set 2 | sirsilla
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | constitucion
# Processing Record 7 of Set 2 | correntina
# Processing Record 8 of Set 2 | changji
# Processing Record 9 of Set 2 | sao jose da laje
# Processing Record 10 of Set 2 | trincomalee
# Processing Record 11 of Set 2 | micomeseng
# Processing Record 12 of Set 2 | mehamn
# Processing Record 13 of Set 2 | buchanan
# Processing Record 14 of Set 2 | comodoro rivadavia
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | dolores
# Processing Record 18 of Set 2 | manbij
# Processing Record 19 of Set 2 | dudinka
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | bongandanga
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | praia da vitoria
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | jalu
# Processing Record 28 of Set 2 | ibicarai
# Processing Record 29 of Set 2 | waw
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | mitsamiouli
# Processing Record 32 of Set 2 | port blair
# Processing Record 33 of Set 2 | tocopilla
# Processing Record 34 of Set 2 | souillac
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | marsh harbour
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | kruisfontein
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | mercedes
# Processing Record 42 of Set 2 | walvis bay
# Processing Record 43 of Set 2 | necochea
# Processing Record 44 of Set 2 | wick
# Processing Record 45 of Set 2 | solwezi
# Processing Record 46 of Set 2 | sikasso
# Processing Record 47 of Set 2 | namibe
# Processing Record 48 of Set 2 | signagi
# City not found. Skipping...
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | merrill
# Processing Record 2 of Set 3 | cancun
# Processing Record 3 of Set 3 | richards bay
# Processing Record 4 of Set 3 | samsun
# Processing Record 5 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 3 | maniitsoq
# Processing Record 7 of Set 3 | elat
# Processing Record 8 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 3 | husavik
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | tortoli
# Processing Record 12 of Set 3 | bandarbeyla
# Processing Record 13 of Set 3 | shinpokh
# Processing Record 14 of Set 3 | vigrestad
# Processing Record 15 of Set 3 | huarmey
# Processing Record 16 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | oksfjord
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | najran
# Processing Record 22 of Set 3 | piet retief
# Processing Record 23 of Set 3 | mabaruma
# Processing Record 24 of Set 3 | sao jose da coroa grande
# Processing Record 25 of Set 3 | madras
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | samana
# Processing Record 29 of Set 3 | vesele
# Processing Record 30 of Set 3 | ostroleka
# Processing Record 31 of Set 3 | gwadar
# Processing Record 32 of Set 3 | san miguel
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | saint-pierre
# Processing Record 35 of Set 3 | santa rita do sapucai
# Processing Record 36 of Set 3 | loutra
# Processing Record 37 of Set 3 | terre haute
# Processing Record 38 of Set 3 | kalmunai
# Processing Record 39 of Set 3 | katra
# Processing Record 40 of Set 3 | caxito
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | kabarnet
# Processing Record 43 of Set 3 | novobelokatay
# Processing Record 44 of Set 3 | khonsar
# City not found. Skipping...
# Processing Record 45 of Set 3 | adrar
# Processing Record 46 of Set 3 | salalah
# Processing Record 47 of Set 3 | dapaong
# Processing Record 48 of Set 3 | klaksvik
# Processing Record 49 of Set 3 | umm kaddadah
# Processing Record 50 of Set 3 | saint-paul
# Processing Record 1 of Set 4 | lubango
# Processing Record 2 of Set 4 | santa luzia
# Processing Record 3 of Set 4 | busselton
# Processing Record 4 of Set 4 | belmonte
# Processing Record 5 of Set 4 | muisne
# Processing Record 6 of Set 4 | ariquemes
# Processing Record 7 of Set 4 | grootfontein
# Processing Record 8 of Set 4 | tiznit
# Processing Record 9 of Set 4 | tessalit
# Processing Record 10 of Set 4 | banda aceh
# Processing Record 11 of Set 4 | kondinskoye
# Processing Record 12 of Set 4 | los llanos de aridane
# Processing Record 13 of Set 4 | constantine
# Processing Record 14 of Set 4 | acari
# Processing Record 15 of Set 4 | saquarema
# Processing Record 16 of Set 4 | ulcinj
# Processing Record 17 of Set 4 | abha
# Processing Record 18 of Set 4 | antofagasta
# Processing Record 19 of Set 4 | bilma
# Processing Record 20 of Set 4 | lagoa
# Processing Record 21 of Set 4 | padang
# Processing Record 22 of Set 4 | colares
# Processing Record 23 of Set 4 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 24 of Set 4 | starkville
# Processing Record 25 of Set 4 | aktau
# Processing Record 26 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 27 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 4 | hauterive
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | mbaiki
# Processing Record 31 of Set 4 | minab
# Processing Record 32 of Set 4 | senanga
# Processing Record 33 of Set 4 | camacha
# Processing Record 34 of Set 4 | vestmanna
# Processing Record 35 of Set 4 | abu dhabi
# Processing Record 36 of Set 4 | bathsheba
# Processing Record 37 of Set 4 | oyem
# Processing Record 38 of Set 4 | tikrit
# Processing Record 39 of Set 4 | cap malheureux
# Processing Record 40 of Set 4 | awjilah
# Processing Record 41 of Set 4 | farsund
# Processing Record 42 of Set 4 | port-gentil
# Processing Record 43 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 4 | bon air
# Processing Record 45 of Set 4 | jawa
# Processing Record 46 of Set 4 | beira
# Processing Record 47 of Set 4 | albemarle
# Processing Record 48 of Set 4 | tyukalinsk
# Processing Record 49 of Set 4 | asfi
# Processing Record 50 of Set 4 | la union
# Processing Record 1 of Set 5 | coquimbo
# Processing Record 2 of Set 5 | mouila
# Processing Record 3 of Set 5 | oussouye
# Processing Record 4 of Set 5 | gat
# Processing Record 5 of Set 5 | dom pedrito
# Processing Record 6 of Set 5 | dwarka
# Processing Record 7 of Set 5 | upata
# Processing Record 8 of Set 5 | ardesen
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | rio gallegos
# Processing Record 11 of Set 5 | laufen
# Processing Record 12 of Set 5 | kaisiadorys
# Processing Record 13 of Set 5 | moramanga
# Processing Record 14 of Set 5 | berlevag
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | breytovo
# Processing Record 17 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 5 | haldibari
# Processing Record 19 of Set 5 | terenos
# Processing Record 20 of Set 5 | mocuba
# Processing Record 21 of Set 5 | el balyana
# City not found. Skipping...
# Processing Record 22 of Set 5 | mecca
# Processing Record 23 of Set 5 | lungi
# Processing Record 24 of Set 5 | lodja
# Processing Record 25 of Set 5 | binga
# Processing Record 26 of Set 5 | lichinga
# Processing Record 27 of Set 5 | spas-demensk
# Processing Record 28 of Set 5 | jabinyanah
# Processing Record 29 of Set 5 | bougouni
# Processing Record 30 of Set 5 | burica
# City not found. Skipping...
# Processing Record 31 of Set 5 | kerteminde
# Processing Record 32 of Set 5 | leh
# Processing Record 33 of Set 5 | mayor pablo lagerenza
# Processing Record 34 of Set 5 | schela
# Processing Record 35 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 5 | sevierville
# Processing Record 37 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 5 | vestmannaeyjar
# Processing Record 39 of Set 5 | plettenberg bay
# Processing Record 40 of Set 5 | araouane
# Processing Record 41 of Set 5 | salamiyah
# Processing Record 42 of Set 5 | casma
# Processing Record 43 of Set 5 | ozinki
# Processing Record 44 of Set 5 | serenje
# Processing Record 45 of Set 5 | skoczow
# Processing Record 46 of Set 5 | abu samrah
# Processing Record 47 of Set 5 | ambanja
# Processing Record 48 of Set 5 | olafsvik
# Processing Record 49 of Set 5 | khipro
# Processing Record 50 of Set 5 | sept-iles
# Processing Record 1 of Set 6 | niono
# Processing Record 2 of Set 6 | paonta sahib
# Processing Record 3 of Set 6 | george
# Processing Record 4 of Set 6 | quatre cocos
# Processing Record 5 of Set 6 | mehriz
# Processing Record 6 of Set 6 | lulea
# Processing Record 7 of Set 6 | grand gaube
# Processing Record 8 of Set 6 | sabzevar
# Processing Record 9 of Set 6 | chastoozerye
# City not found. Skipping...
# Processing Record 10 of Set 6 | reconquista
# Processing Record 11 of Set 6 | sabanalarga
# Processing Record 12 of Set 6 | toila
# Processing Record 13 of Set 6 | zherdevka
# Processing Record 14 of Set 6 | atar
# Processing Record 15 of Set 6 | belaya glina
# Processing Record 16 of Set 6 | karasjok
# Processing Record 17 of Set 6 | klyuchi
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | locri
# Processing Record 20 of Set 6 | izhma
# Processing Record 21 of Set 6 | zhezkazgan
# Processing Record 22 of Set 6 | tabory
# Processing Record 23 of Set 6 | el puerto de santa maria
# Processing Record 24 of Set 6 | touros
# Processing Record 25 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 6 | marsaxlokk
# Processing Record 27 of Set 6 | kutum
# Processing Record 28 of Set 6 | garhi khairo
# Processing Record 29 of Set 6 | methoni
# Processing Record 30 of Set 6 | morondava
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | castro
# Processing Record 33 of Set 6 | goure
# Processing Record 34 of Set 6 | khurai
# Processing Record 35 of Set 6 | chancay
# Processing Record 36 of Set 6 | matucana
# Processing Record 37 of Set 6 | alora
# Processing Record 38 of Set 6 | borama
# City not found. Skipping...
# Processing Record 39 of Set 6 | barranca
# Processing Record 40 of Set 6 | viedma
# Processing Record 41 of Set 6 | salisbury
# Processing Record 42 of Set 6 | yar-sale
# Processing Record 43 of Set 6 | asyut
# Processing Record 44 of Set 6 | borova
# Processing Record 45 of Set 6 | tambopata
# Processing Record 46 of Set 6 | yanam
# Processing Record 47 of Set 6 | lokosovo
# Processing Record 48 of Set 6 | southport
# Processing Record 49 of Set 6 | edeia
# Processing Record 50 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 7 | irmo
# Processing Record 2 of Set 7 | yenagoa
# Processing Record 3 of Set 7 | mariental
# Processing Record 4 of Set 7 | port charlotte
# Processing Record 5 of Set 7 | kant
# Processing Record 6 of Set 7 | ayame
# Processing Record 7 of Set 7 | zaranj
# Processing Record 8 of Set 7 | cockburn town
# Processing Record 9 of Set 7 | ratnagiri
# Processing Record 10 of Set 7 | hirson
# Processing Record 11 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 7 | koran
# Processing Record 13 of Set 7 | ovalle
# Processing Record 14 of Set 7 | san pedro
# Processing Record 15 of Set 7 | tombouctou
# Processing Record 16 of Set 7 | baherden
# Processing Record 17 of Set 7 | katete
# Processing Record 18 of Set 7 | odesskoye
# Processing Record 19 of Set 7 | uray
# Processing Record 20 of Set 7 | moultrie
# Processing Record 21 of Set 7 | marawi
# Processing Record 22 of Set 7 | shushtar
# Processing Record 23 of Set 7 | balaka
# Processing Record 24 of Set 7 | roald
# Processing Record 25 of Set 7 | dhuburi
# Processing Record 26 of Set 7 | piacabucu
# Processing Record 27 of Set 7 | qazigund
# Processing Record 28 of Set 7 | odweyne
# Processing Record 29 of Set 7 | saint anthony
# Processing Record 30 of Set 7 | hambantota
# Processing Record 31 of Set 7 | the valley
# Processing Record 32 of Set 7 | gumdag
# Processing Record 33 of Set 7 | soavinandriana
# Processing Record 34 of Set 7 | coro
# Processing Record 35 of Set 7 | zambezi
# Processing Record 36 of Set 7 | grindavik
# Processing Record 37 of Set 7 | obo
# Processing Record 38 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 39 of Set 7 | birao
# Processing Record 40 of Set 7 | novouzensk
# Processing Record 41 of Set 7 | san francisco
# Processing Record 42 of Set 7 | saint-joseph
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | brae
# Processing Record 45 of Set 7 | keti bandar
# Processing Record 46 of Set 7 | nouadhibou
# Processing Record 47 of Set 7 | digby
# Processing Record 48 of Set 7 | nuuk
# Processing Record 49 of Set 7 | wilmington
# Processing Record 50 of Set 7 | baft
# Processing Record 1 of Set 8 | kyabe
# Processing Record 2 of Set 8 | dobele
# Processing Record 3 of Set 8 | kiruna
# Processing Record 4 of Set 8 | den helder
# Processing Record 5 of Set 8 | vasai
# Processing Record 6 of Set 8 | saint albans
# Processing Record 7 of Set 8 | harbour breton
# Processing Record 8 of Set 8 | puerto colombia
# Processing Record 9 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 8 | general pico
# Processing Record 11 of Set 8 | dori
# Processing Record 12 of Set 8 | periyapatti
# Processing Record 13 of Set 8 | dunmore town
# Processing Record 14 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 15 of Set 8 | susehri
# Processing Record 16 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 8 | paita
# Processing Record 18 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 19 of Set 8 | sakakah
# Processing Record 20 of Set 8 | carballo
# Processing Record 21 of Set 8 | puerto madryn
# Processing Record 22 of Set 8 | kayes
# Processing Record 23 of Set 8 | iki-burul
# Processing Record 24 of Set 8 | pitea
# Processing Record 25 of Set 8 | zapolyarnyy
# Processing Record 26 of Set 8 | stokmarknes
# Processing Record 27 of Set 8 | agadez
# Processing Record 28 of Set 8 | baltiysk
# Processing Record 29 of Set 8 | gazanjyk
# Processing Record 30 of Set 8 | shache
# Processing Record 31 of Set 8 | sidi ali
# Processing Record 32 of Set 8 | xuddur
# Processing Record 33 of Set 8 | dahanu
# Processing Record 34 of Set 8 | camopi
# Processing Record 35 of Set 8 | caravelas
# Processing Record 36 of Set 8 | andenes
# Processing Record 37 of Set 8 | mao
# Processing Record 38 of Set 8 | huntington
# Processing Record 39 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 8 | odienne
# Processing Record 41 of Set 8 | vardo
# Processing Record 42 of Set 8 | ushtobe
# Processing Record 43 of Set 8 | kedrovyy
# Processing Record 44 of Set 8 | mantua
# Processing Record 45 of Set 8 | balkanabat
# Processing Record 46 of Set 8 | daura
# Processing Record 47 of Set 8 | angoche
# Processing Record 48 of Set 8 | rabo de peixe
# Processing Record 49 of Set 8 | pangnirtung
# Processing Record 50 of Set 8 | sisimiut
# Processing Record 1 of Set 9 | praia
# Processing Record 2 of Set 9 | sotnikovskoye
# Processing Record 3 of Set 9 | kuytun
# Processing Record 4 of Set 9 | gardner
# Processing Record 5 of Set 9 | mali zvornik
# Processing Record 6 of Set 9 | veraval
# Processing Record 7 of Set 9 | tapes
# Processing Record 8 of Set 9 | korla
# Processing Record 9 of Set 9 | bulri
# Processing Record 10 of Set 9 | dahod
# Processing Record 11 of Set 9 | depalpur
# Processing Record 12 of Set 9 | buritis
# Processing Record 13 of Set 9 | kaabong
# Processing Record 14 of Set 9 | goderich
# Processing Record 15 of Set 9 | faya
# Processing Record 16 of Set 9 | layou
# Processing Record 17 of Set 9 | mtambile
# Processing Record 18 of Set 9 | lima
# Processing Record 19 of Set 9 | rocha
# Processing Record 20 of Set 9 | eyl
# Processing Record 21 of Set 9 | sao paulo de olivenca
# Processing Record 22 of Set 9 | kashi
# Processing Record 23 of Set 9 | shahr-e babak
# Processing Record 24 of Set 9 | senno
# Processing Record 25 of Set 9 | rio de janeiro
# Processing Record 26 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 9 | ostrovnoy
# Processing Record 28 of Set 9 | chingola
# Processing Record 29 of Set 9 | matara
# Processing Record 30 of Set 9 | nioro
# Processing Record 31 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 9 | bara
# Processing Record 33 of Set 9 | novovasylivka
# Processing Record 34 of Set 9 | iranshahr
# Processing Record 35 of Set 9 | kavaratti
# Processing Record 36 of Set 9 | hualmay
# Processing Record 37 of Set 9 | moroto
# Processing Record 38 of Set 9 | biala podlaska
# Processing Record 39 of Set 9 | rzeszow
# Processing Record 40 of Set 9 | herat
# Processing Record 41 of Set 9 | sturgeon bay
# Processing Record 42 of Set 9 | eganville
# Processing Record 43 of Set 9 | plerin
# Processing Record 44 of Set 9 | tayginka
# Processing Record 45 of Set 9 | kemijarvi
# Processing Record 46 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 47 of Set 9 | lewisporte
# Processing Record 48 of Set 9 | clevelandia
# Processing Record 49 of Set 9 | gari
# Processing Record 50 of Set 9 | bequimao
# Processing Record 1 of Set 10 | karoi
# Processing Record 2 of Set 10 | bafra
# Processing Record 3 of Set 10 | hobyo
# Processing Record 4 of Set 10 | lasa
# Processing Record 5 of Set 10 | chapais
# Processing Record 6 of Set 10 | baillif
# Processing Record 7 of Set 10 | danilovka
# Processing Record 8 of Set 10 | ayagoz
# Processing Record 9 of Set 10 | sorland
# Processing Record 10 of Set 10 | muzhi
# Processing Record 11 of Set 10 | bethanien
# Processing Record 12 of Set 10 | raga
# Processing Record 13 of Set 10 | carnarvon
# Processing Record 14 of Set 10 | amapa
# Processing Record 15 of Set 10 | shetpe
# Processing Record 16 of Set 10 | sur
# Processing Record 17 of Set 10 | cabedelo
# Processing Record 18 of Set 10 | thilogne
# City not found. Skipping...
# Processing Record 19 of Set 10 | inhambane
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | kuryk
# Processing Record 22 of Set 10 | sorrento
# Processing Record 23 of Set 10 | malanje
# Processing Record 24 of Set 10 | salinopolis
# Processing Record 25 of Set 10 | kyshtovka
# Processing Record 26 of Set 10 | awbari
# Processing Record 27 of Set 10 | grahamstown
# Processing Record 28 of Set 10 | longuenesse
# Processing Record 29 of Set 10 | bereda
# Processing Record 30 of Set 10 | arlit
# Processing Record 31 of Set 10 | madison
# Processing Record 32 of Set 10 | massape
# Processing Record 33 of Set 10 | wanlaweyn
# Processing Record 34 of Set 10 | eydhafushi
# Processing Record 35 of Set 10 | saint-francois
# Processing Record 36 of Set 10 | canoinhas
# Processing Record 37 of Set 10 | ritchie
# Processing Record 38 of Set 10 | gambo
# Processing Record 39 of Set 10 | itarema
# Processing Record 40 of Set 10 | terrak
# Processing Record 41 of Set 10 | asilah
# Processing Record 42 of Set 10 | olot
# Processing Record 43 of Set 10 | san rafael del sur
# Processing Record 44 of Set 10 | kamenka
# Processing Record 45 of Set 10 | paamiut
# Processing Record 46 of Set 10 | le vauclin
# Processing Record 47 of Set 10 | boditi
# Processing Record 48 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 49 of Set 10 | pontes e lacerda
# Processing Record 50 of Set 10 | bouake
# Processing Record 1 of Set 11 | druzhba
# Processing Record 2 of Set 11 | shubarkuduk
# Processing Record 3 of Set 11 | fonte boa
# Processing Record 4 of Set 11 | utena
# Processing Record 5 of Set 11 | chernyy yar
# Processing Record 6 of Set 11 | hearst
# Processing Record 7 of Set 11 | chicama
# Processing Record 8 of Set 11 | prudy
# Processing Record 9 of Set 11 | reo
# Processing Record 10 of Set 11 | qaqortoq
# Processing Record 11 of Set 11 | turkmenabat
# Processing Record 12 of Set 11 | nybro
# Processing Record 13 of Set 11 | mogadishu
# Processing Record 14 of Set 11 | bahir dar
# Processing Record 15 of Set 11 | cayeli
# Processing Record 16 of Set 11 | abalak
# Processing Record 17 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 18 of Set 11 | horta
# Processing Record 19 of Set 11 | buraydah
# Processing Record 20 of Set 11 | rio verde de mato grosso
# Processing Record 21 of Set 11 | vredendal
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | maceio
# Processing Record 24 of Set 11 | darnah
# Processing Record 25 of Set 11 | bekhtery
# Processing Record 26 of Set 11 | havelock
# Processing Record 27 of Set 11 | gazli
# Processing Record 28 of Set 11 | jumla
# Processing Record 29 of Set 11 | kharan
# Processing Record 30 of Set 11 | ilhabela
# Processing Record 31 of Set 11 | lancaster
# Processing Record 32 of Set 11 | pisco
# Processing Record 33 of Set 11 | moose factory
# Processing Record 34 of Set 11 | thompson
# Processing Record 35 of Set 11 | parati
# Processing Record 36 of Set 11 | pozo colorado
# Processing Record 37 of Set 11 | brest
# Processing Record 38 of Set 11 | tskneti
# Processing Record 39 of Set 11 | bardsir
# Processing Record 40 of Set 11 | tubuala
# Processing Record 41 of Set 11 | barra patuca
# Processing Record 42 of Set 11 | corinto
# Processing Record 43 of Set 11 | andra
# Processing Record 44 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 45 of Set 11 | nizwa
# Processing Record 46 of Set 11 | havre-saint-pierre
# Processing Record 47 of Set 11 | raisinghnagar
# Processing Record 48 of Set 11 | ndele
# Processing Record 49 of Set 11 | gobabis
# Processing Record 50 of Set 11 | rantoul
# Processing Record 1 of Set 12 | ajdabiya
# Processing Record 2 of Set 12 | tabuk
# Processing Record 3 of Set 12 | yelan
# Processing Record 4 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 12 | kilemary
# Processing Record 6 of Set 12 | gusau
# Processing Record 7 of Set 12 | rawson
# Processing Record 8 of Set 12 | brodokalmak
# Processing Record 9 of Set 12 | ilesha
# Processing Record 10 of Set 12 | banyo
# Processing Record 11 of Set 12 | omboue
# Processing Record 12 of Set 12 | ribeira brava
# Processing Record 13 of Set 12 | jaunpur
# Processing Record 14 of Set 12 | boende
# Processing Record 15 of Set 12 | krasnobrodskiy
# Processing Record 16 of Set 12 | loiza
# Processing Record 17 of Set 12 | rawah
# Processing Record 18 of Set 12 | moron
# Processing Record 19 of Set 12 | alanya
# Processing Record 20 of Set 12 | serebryansk
# Processing Record 21 of Set 12 | george town
# Processing Record 22 of Set 12 | san carlos de bariloche
# Processing Record 23 of Set 12 | sembe
# Processing Record 24 of Set 12 | solikamsk
# Processing Record 25 of Set 12 | adeje
# Processing Record 26 of Set 12 | riyadh
# Processing Record 27 of Set 12 | zarautz
# Processing Record 28 of Set 12 | benghazi
# Processing Record 29 of Set 12 | la palma
# Processing Record 30 of Set 12 | gazalkent
# Processing Record 31 of Set 12 | hakkari
# Processing Record 32 of Set 12 | clarksburg
# Processing Record 33 of Set 12 | corner brook
# Processing Record 34 of Set 12 | colonia
# Processing Record 35 of Set 12 | cururupu
# Processing Record 36 of Set 12 | iralaya
# Processing Record 37 of Set 12 | butembo
# Processing Record 38 of Set 12 | mastic beach
# Processing Record 39 of Set 12 | ejura
# Processing Record 40 of Set 12 | suleja
# Processing Record 41 of Set 12 | ravar
# Processing Record 42 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 12 | columbia
# Processing Record 44 of Set 12 | kangaatsiaq
# Processing Record 45 of Set 12 | villefranche-de-rouergue
# Processing Record 46 of Set 12 | bugulma
# Processing Record 47 of Set 12 | khoy
# Processing Record 48 of Set 12 | presidencia roque saenz pena
# Processing Record 49 of Set 12 | linkoping
# Processing Record 50 of Set 12 | sabha
# Processing Record 1 of Set 13 | markala
# Processing Record 2 of Set 13 | jinka
# Processing Record 3 of Set 13 | bonfim
# Processing Record 4 of Set 13 | astana
# Processing Record 5 of Set 13 | santa lucia
# Processing Record 6 of Set 13 | ashoknagar
# Processing Record 7 of Set 13 | muhos
# Processing Record 8 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 9 of Set 13 | edd
# Processing Record 10 of Set 13 | muros
# Processing Record 11 of Set 13 | marmarion
# Processing Record 12 of Set 13 | iquique
# Processing Record 13 of Set 13 | semey
# Processing Record 14 of Set 13 | calbuco
# Processing Record 15 of Set 13 | la mana
# Processing Record 16 of Set 13 | tashla
# Processing Record 17 of Set 13 | vila velha
# Processing Record 18 of Set 13 | karpathos
# Processing Record 19 of Set 13 | ferme-neuve
# Processing Record 20 of Set 13 | agirish
# Processing Record 21 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 13 | maldonado
# Processing Record 23 of Set 13 | derzhavinsk
# Processing Record 24 of Set 13 | san martin
# Processing Record 25 of Set 13 | morristown
# Processing Record 26 of Set 13 | luanda
# Processing Record 27 of Set 13 | priiskovyy
# Processing Record 28 of Set 13 | petawawa
# Processing Record 29 of Set 13 | mpongwe
# Processing Record 30 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 13 | tefe
# Processing Record 32 of Set 13 | shuya
# Processing Record 33 of Set 13 | dmytrivka
# Processing Record 34 of Set 13 | yarmouth
# Processing Record 35 of Set 13 | farafangana
# Processing Record 36 of Set 13 | raudeberg
# Processing Record 37 of Set 13 | lucapa
# Processing Record 38 of Set 13 | diego de almagro
# Processing Record 39 of Set 13 | verkhnyaya inta
# Processing Record 40 of Set 13 | thinadhoo
# Processing Record 41 of Set 13 | kwakoa
# Processing Record 42 of Set 13 | jiblah
# Processing Record 43 of Set 13 | bauchi
# Processing Record 44 of Set 13 | coihaique
# Processing Record 45 of Set 13 | calvinia
# Processing Record 46 of Set 13 | umarizal
# Processing Record 47 of Set 13 | banepa
# Processing Record 48 of Set 13 | barhi
# Processing Record 49 of Set 13 | benguela
# Processing Record 50 of Set 13 | caribou
# Processing Record 1 of Set 14 | chadiza
# Processing Record 2 of Set 14 | west bend
# Processing Record 3 of Set 14 | cartagena
# Processing Record 4 of Set 14 | nsanje
# Processing Record 5 of Set 14 | porosozero
# Processing Record 6 of Set 14 | doha
# Processing Record 7 of Set 14 | shelburne
# Processing Record 8 of Set 14 | am timan
# Processing Record 9 of Set 14 | abdanan
# Processing Record 10 of Set 14 | presidente medici
# Processing Record 11 of Set 14 | black river
# Processing Record 12 of Set 14 | calabozo
# Processing Record 13 of Set 14 | plast
# Processing Record 14 of Set 14 | osorno
# Processing Record 15 of Set 14 | batticaloa
# Processing Record 16 of Set 14 | synya
# Processing Record 17 of Set 14 | verkh-chebula
# Processing Record 18 of Set 14 | terra rica
# Processing Record 19 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 14 | moundou
# Processing Record 21 of Set 14 | puerto gaitan
# Processing Record 22 of Set 14 | linhares
# Processing Record 23 of Set 14 | guarapari
# Processing Record 24 of Set 14 | vila franca do campo
# Processing Record 25 of Set 14 | sao miguel do araguaia
# Processing Record 26 of Set 14 | bhainsdehi
# Processing Record 27 of Set 14 | jacmel
# Processing Record 28 of Set 14 | dhidhdhoo
# Processing Record 29 of Set 14 | gornyak
# Processing Record 30 of Set 14 | scarborough
# Processing Record 31 of Set 14 | dekar
# Processing Record 32 of Set 14 | venado tuerto
# Processing Record 33 of Set 14 | jasper
# Processing Record 34 of Set 14 | jesenice
# Processing Record 35 of Set 14 | lenger
# Processing Record 36 of Set 14 | dondo
# Processing Record 37 of Set 14 | koutsouras
# Processing Record 38 of Set 14 | oktyabrskoye
# Processing Record 39 of Set 14 | mbinga
# Processing Record 40 of Set 14 | kulhudhuffushi
# Processing Record 41 of Set 14 | tonj
# Processing Record 42 of Set 14 | marktoberdorf
# Processing Record 43 of Set 14 | meiganga
# Processing Record 44 of Set 14 | fort wellington
# Processing Record 45 of Set 14 | deep river
# Processing Record 46 of Set 14 | south venice
# Processing Record 47 of Set 14 | le passage
# Processing Record 48 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 49 of Set 14 | thomaston
# Processing Record 50 of Set 14 | eyrarbakki
# Processing Record 1 of Set 15 | san javier
# Processing Record 2 of Set 15 | corn island
# Processing Record 3 of Set 15 | eskisehir
# Processing Record 4 of Set 15 | nador
# Processing Record 5 of Set 15 | ladario
# Processing Record 6 of Set 15 | puerto quijarro
# Processing Record 7 of Set 15 | gravdal
# Processing Record 8 of Set 15 | vuktyl
# Processing Record 9 of Set 15 | havoysund
# Processing Record 10 of Set 15 | rajauri
# Processing Record 11 of Set 15 | santa barbara de nexe
# Processing Record 12 of Set 15 | fevik
# Processing Record 13 of Set 15 | maragogi
# Processing Record 14 of Set 15 | brigantine
# Processing Record 15 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 15 | skjervoy
# Processing Record 17 of Set 15 | silva jardim
# Processing Record 18 of Set 15 | kedgwick
# Processing Record 19 of Set 15 | port hawkesbury
# Processing Record 20 of Set 15 | dobrinje
# Processing Record 21 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 22 of Set 15 | paris
# Processing Record 23 of Set 15 | marietta
# Processing Record 24 of Set 15 | morrope
# Processing Record 25 of Set 15 | kudahuvadhoo
# Processing Record 26 of Set 15 | puerto carreno
# Processing Record 27 of Set 15 | zlutice
# Processing Record 28 of Set 15 | ponta delgada
# Processing Record 29 of Set 15 | tigre
# Processing Record 30 of Set 15 | magaria
# Processing Record 31 of Set 15 | vols
# Processing Record 32 of Set 15 | chapel hill
# Processing Record 33 of Set 15 | lyubeshiv
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
# Print the length of the city_data list to verify how many cities you have
#len(city_data)
print(len(city_data))
# Out:
# 682

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Georgetown      MY   5.4112  100.3354     87.73        62          20
# 1         Westport      US  41.1415  -73.3579     39.56        64           0
# 2        Nantucket      US  41.2835  -70.0995     39.34        79         100
# 3           Torbay      CA  47.6666  -52.7314     30.97        86         100
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     76.96        94           0
# 5          Ushuaia      AR -54.8000  -68.3000     53.26        43          40
# 6        Cape Town      ZA -33.9258   18.4232     63.37        89          40
# 7            Galle      LK   6.0367   80.2170     80.76        72         100
# 8   Saint-Augustin      CA  51.2260  -58.6502     24.62        77          19
# 9         Saldanha      ZA -33.0117   17.9442     57.25        81           0
#
#    Wind Speed       Description
# 0        8.05        few clouds
# 1        9.22         clear sky
# 2        5.75   overcast clouds
# 3       20.71        heavy snow
# 4       10.36         clear sky
# 5        5.75  scattered clouds
# 6        3.44  scattered clouds
# 7        6.17   overcast clouds
# 8       17.11        few clouds
# 9        2.89         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Georgetown      MY   5.4112  100.3354     87.73        62          20
# 1         Westport      US  41.1415  -73.3579     39.56        64           0
# 2        Nantucket      US  41.2835  -70.0995     39.34        79         100
# 3           Torbay      CA  47.6666  -52.7314     30.97        86         100
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     76.96        94           0
# 5          Ushuaia      AR -54.8000  -68.3000     53.26        43          40
# 6        Cape Town      ZA -33.9258   18.4232     63.37        89          40
# 7            Galle      LK   6.0367   80.2170     80.76        72         100
# 8   Saint-Augustin      CA  51.2260  -58.6502     24.62        77          19
# 9         Saldanha      ZA -33.0117   17.9442     57.25        81           0
#
#    Wind Speed       Description
# 0        8.05        few clouds
# 1        9.22         clear sky
# 2        5.75   overcast clouds
# 3       20.71        heavy snow
# 4       10.36         clear sky
# 5        5.75  scattered clouds
# 6        3.44  scattered clouds
# 7        6.17   overcast clouds
# 8       17.11        few clouds
# 9        2.89         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
