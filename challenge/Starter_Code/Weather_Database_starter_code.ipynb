# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | la romana
# Processing Record 2 of Set 1 | lodwar
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | sakakah
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | richards bay
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | robertsport
# Processing Record 16 of Set 1 | saint george
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | arlit
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | aksum
# Processing Record 23 of Set 1 | mitsamiouli
# Processing Record 24 of Set 1 | sal rei
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | corn island
# Processing Record 27 of Set 1 | nanortalik
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | jalingo
# Processing Record 31 of Set 1 | vardo
# Processing Record 32 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | turkistan
# Processing Record 35 of Set 1 | olavarria
# Processing Record 36 of Set 1 | paamiut
# Processing Record 37 of Set 1 | vagur
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | rabak
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | dakar
# Processing Record 44 of Set 1 | kiruna
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | victoria
# Processing Record 47 of Set 1 | marzuq
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | ust-tsilma
# Processing Record 50 of Set 1 | port-cartier
# Processing Record 1 of Set 2 | wawa
# Processing Record 2 of Set 2 | oistins
# Processing Record 3 of Set 2 | sharya
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | bilma
# Processing Record 6 of Set 2 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 2 | vestmannaeyjar
# Processing Record 8 of Set 2 | aksarka
# Processing Record 9 of Set 2 | santa rosa
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | naantali
# Processing Record 12 of Set 2 | portree
# Processing Record 13 of Set 2 | bahia blanca
# Processing Record 14 of Set 2 | yar-sale
# Processing Record 15 of Set 2 | chiredzi
# Processing Record 16 of Set 2 | kolokani
# Processing Record 17 of Set 2 | qaqortoq
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | krasnoselkup
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | piet retief
# Processing Record 22 of Set 2 | tabora
# Processing Record 23 of Set 2 | margate
# Processing Record 24 of Set 2 | quime
# Processing Record 25 of Set 2 | matsanga
# City not found. Skipping...
# Processing Record 26 of Set 2 | nikki
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 2 | murighiol
# Processing Record 30 of Set 2 | warrington
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 2 | desnogorsk
# Processing Record 34 of Set 2 | kulzeb
# City not found. Skipping...
# Processing Record 35 of Set 2 | asfi
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | nadym
# Processing Record 38 of Set 2 | kudahuvadhoo
# Processing Record 39 of Set 2 | muzaffarpur
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | husavik
# Processing Record 42 of Set 2 | aquiraz
# Processing Record 43 of Set 2 | dingle
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | sjenica
# Processing Record 46 of Set 2 | nouadhibou
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | korla
# Processing Record 49 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 50 of Set 2 | coihaique
# Processing Record 1 of Set 3 | kargasok
# Processing Record 2 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 3 | sao gabriel da cachoeira
# Processing Record 4 of Set 3 | luanda
# Processing Record 5 of Set 3 | sokoto
# Processing Record 6 of Set 3 | matara
# Processing Record 7 of Set 3 | kedrovyy
# Processing Record 8 of Set 3 | goaigoaza
# City not found. Skipping...
# Processing Record 9 of Set 3 | abha
# Processing Record 10 of Set 3 | itarema
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | tiznit
# Processing Record 14 of Set 3 | dalgopol
# Processing Record 15 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 3 | pokrovskoye
# Processing Record 17 of Set 3 | saint-francois
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | bandarbeyla
# Processing Record 20 of Set 3 | grand-santi
# Processing Record 21 of Set 3 | idah
# Processing Record 22 of Set 3 | bernay
# Processing Record 23 of Set 3 | oyon
# Processing Record 24 of Set 3 | chester
# Processing Record 25 of Set 3 | rio verde de mato grosso
# Processing Record 26 of Set 3 | saint-denis
# Processing Record 27 of Set 3 | sao joao da barra
# Processing Record 28 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 34 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | takoradi
# Processing Record 37 of Set 3 | olafsvik
# Processing Record 38 of Set 3 | azare
# Processing Record 39 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 3 | kaspiysk
# Processing Record 41 of Set 3 | sao filipe
# Processing Record 42 of Set 3 | wa
# City not found. Skipping...
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | hualmay
# Processing Record 45 of Set 3 | kilindoni
# Processing Record 46 of Set 3 | miraflores
# Processing Record 47 of Set 3 | punta arenas
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | ravar
# Processing Record 50 of Set 3 | adrar
# Processing Record 1 of Set 4 | necochea
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | sinnamary
# Processing Record 4 of Set 4 | bathsheba
# Processing Record 5 of Set 4 | gagnoa
# Processing Record 6 of Set 4 | melfi
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | kinanah
# City not found. Skipping...
# Processing Record 9 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 10 of Set 4 | quatre cocos
# Processing Record 11 of Set 4 | ushtobe
# Processing Record 12 of Set 4 | bulancak
# Processing Record 13 of Set 4 | havoysund
# Processing Record 14 of Set 4 | strezhevoy
# Processing Record 15 of Set 4 | la palma
# Processing Record 16 of Set 4 | farsund
# Processing Record 17 of Set 4 | maldonado
# Processing Record 18 of Set 4 | belmonte
# Processing Record 19 of Set 4 | nacala
# Processing Record 20 of Set 4 | havelock
# Processing Record 21 of Set 4 | belyy yar
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | hargeysa
# Processing Record 24 of Set 4 | scarborough
# Processing Record 25 of Set 4 | vila franca do campo
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | nantucket
# Processing Record 28 of Set 4 | chimbote
# Processing Record 29 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 4 | tabas
# Processing Record 31 of Set 4 | chapais
# Processing Record 32 of Set 4 | bonthe
# Processing Record 33 of Set 4 | grand gaube
# Processing Record 34 of Set 4 | zaraysk
# Processing Record 35 of Set 4 | aksu
# Processing Record 36 of Set 4 | keti bandar
# Processing Record 37 of Set 4 | hendrina
# Processing Record 38 of Set 4 | saint-tite
# Processing Record 39 of Set 4 | viransehir
# Processing Record 40 of Set 4 | san cristobal
# Processing Record 41 of Set 4 | eydhafushi
# Processing Record 42 of Set 4 | lagoa
# Processing Record 43 of Set 4 | livramento
# Processing Record 44 of Set 4 | kristiinankaupunki
# Processing Record 45 of Set 4 | joshimath
# Processing Record 46 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 4 | los llanos de aridane
# Processing Record 48 of Set 4 | rio grande
# Processing Record 49 of Set 4 | mana
# Processing Record 50 of Set 4 | gumla
# Processing Record 1 of Set 5 | yei
# Processing Record 2 of Set 5 | les cayes
# Processing Record 3 of Set 5 | cervo
# Processing Record 4 of Set 5 | manaira
# Processing Record 5 of Set 5 | cockburn town
# Processing Record 6 of Set 5 | bud
# Processing Record 7 of Set 5 | biltine
# Processing Record 8 of Set 5 | dogondoutchi
# Processing Record 9 of Set 5 | bafq
# Processing Record 10 of Set 5 | malakal
# Processing Record 11 of Set 5 | pinheiro machado
# Processing Record 12 of Set 5 | soller
# Processing Record 13 of Set 5 | afyonkarahisar
# Processing Record 14 of Set 5 | santa cruz cabralia
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | alunitdag
# City not found. Skipping...
# Processing Record 17 of Set 5 | arnsberg
# Processing Record 18 of Set 5 | kaduna
# Processing Record 19 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 5 | kushmurun
# Processing Record 21 of Set 5 | araouane
# Processing Record 22 of Set 5 | rawson
# Processing Record 23 of Set 5 | bam
# Processing Record 24 of Set 5 | roxana
# Processing Record 25 of Set 5 | eyl
# Processing Record 26 of Set 5 | mlandizi
# Processing Record 27 of Set 5 | san pedro
# Processing Record 28 of Set 5 | sarmanovo
# Processing Record 29 of Set 5 | begun
# Processing Record 30 of Set 5 | jacareacanga
# Processing Record 31 of Set 5 | vallenar
# Processing Record 32 of Set 5 | ostrovnoy
# Processing Record 33 of Set 5 | ankazoabo
# Processing Record 34 of Set 5 | hobyo
# Processing Record 35 of Set 5 | aripuana
# Processing Record 36 of Set 5 | ceres
# Processing Record 37 of Set 5 | lerwick
# Processing Record 38 of Set 5 | cabedelo
# Processing Record 39 of Set 5 | ivankiv
# Processing Record 40 of Set 5 | boa vista
# Processing Record 41 of Set 5 | macas
# Processing Record 42 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 5 | koygorodok
# Processing Record 44 of Set 5 | beyneu
# Processing Record 45 of Set 5 | oranjemund
# Processing Record 46 of Set 5 | santa maria
# Processing Record 47 of Set 5 | kharitonovo
# Processing Record 48 of Set 5 | mahon
# Processing Record 49 of Set 5 | eidfjord
# Processing Record 50 of Set 5 | kholm
# Processing Record 1 of Set 6 | kidal
# Processing Record 2 of Set 6 | lumeje
# Processing Record 3 of Set 6 | buraydah
# Processing Record 4 of Set 6 | porto novo
# Processing Record 5 of Set 6 | menongue
# Processing Record 6 of Set 6 | inhambane
# Processing Record 7 of Set 6 | praia da vitoria
# Processing Record 8 of Set 6 | masumbwe
# Processing Record 9 of Set 6 | omboue
# Processing Record 10 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 11 of Set 6 | saint andrews
# Processing Record 12 of Set 6 | labytnangi
# Processing Record 13 of Set 6 | kolyubakino
# Processing Record 14 of Set 6 | charyshskoye
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 6 | fier
# Processing Record 17 of Set 6 | wamba
# Processing Record 18 of Set 6 | henties bay
# Processing Record 19 of Set 6 | grasse
# Processing Record 20 of Set 6 | sheltozero
# Processing Record 21 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 6 | svetlogorsk
# Processing Record 23 of Set 6 | inirida
# Processing Record 24 of Set 6 | emba
# Processing Record 25 of Set 6 | baraut
# Processing Record 26 of Set 6 | humaita
# Processing Record 27 of Set 6 | abalak
# Processing Record 28 of Set 6 | birin
# Processing Record 29 of Set 6 | pointe michel
# Processing Record 30 of Set 6 | novouzensk
# Processing Record 31 of Set 6 | parrita
# Processing Record 32 of Set 6 | fonte boa
# Processing Record 33 of Set 6 | camopi
# Processing Record 34 of Set 6 | butembo
# Processing Record 35 of Set 6 | rudsar
# Processing Record 36 of Set 6 | artyom
# Processing Record 37 of Set 6 | cururupu
# Processing Record 38 of Set 6 | pimampiro
# Processing Record 39 of Set 6 | saint-augustin
# Processing Record 40 of Set 6 | cornwall
# Processing Record 41 of Set 6 | rize
# Processing Record 42 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 6 | meghradzor
# Processing Record 45 of Set 6 | kayerkan
# Processing Record 46 of Set 6 | rorvik
# Processing Record 47 of Set 6 | benidorm
# Processing Record 48 of Set 6 | vicuna
# Processing Record 49 of Set 6 | caravelas
# Processing Record 50 of Set 6 | koboko
# Processing Record 1 of Set 7 | ipameri
# Processing Record 2 of Set 7 | san alberto
# Processing Record 3 of Set 7 | touros
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | minab
# Processing Record 6 of Set 7 | lukovetskiy
# Processing Record 7 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 7 | la ligua
# Processing Record 9 of Set 7 | shorewood
# Processing Record 10 of Set 7 | urengoy
# Processing Record 11 of Set 7 | lujan
# Processing Record 12 of Set 7 | karakose
# City not found. Skipping...
# Processing Record 13 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 7 | comodoro rivadavia
# Processing Record 15 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 7 | floro
# Processing Record 17 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 7 | saint-joseph
# Processing Record 19 of Set 7 | castro
# Processing Record 20 of Set 7 | penzance
# Processing Record 21 of Set 7 | luau
# Processing Record 22 of Set 7 | cortona
# Processing Record 23 of Set 7 | valparaiso
# Processing Record 24 of Set 7 | barra patuca
# Processing Record 25 of Set 7 | bida
# Processing Record 26 of Set 7 | amol
# Processing Record 27 of Set 7 | khandbari
# Processing Record 28 of Set 7 | marawi
# Processing Record 29 of Set 7 | saint-paul-les-dax
# Processing Record 30 of Set 7 | vagay
# Processing Record 31 of Set 7 | zheleznodorozhnyy
# Processing Record 32 of Set 7 | haldia
# Processing Record 33 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 7 | springbok
# Processing Record 35 of Set 7 | san andres
# Processing Record 36 of Set 7 | kalangala
# Processing Record 37 of Set 7 | tarabha
# Processing Record 38 of Set 7 | lisakovsk
# Processing Record 39 of Set 7 | mutis
# Processing Record 40 of Set 7 | gamboma
# Processing Record 41 of Set 7 | laguna
# Processing Record 42 of Set 7 | fulton
# Processing Record 43 of Set 7 | ilinge
# Processing Record 44 of Set 7 | antofagasta
# Processing Record 45 of Set 7 | constantine
# Processing Record 46 of Set 7 | coquimbo
# Processing Record 47 of Set 7 | piacenza
# Processing Record 48 of Set 7 | kabinda
# Processing Record 49 of Set 7 | diu
# Processing Record 50 of Set 7 | igarka
# Processing Record 1 of Set 8 | synya
# Processing Record 2 of Set 8 | santa marta
# Processing Record 3 of Set 8 | bhatkal
# Processing Record 4 of Set 8 | lima
# Processing Record 5 of Set 8 | altay
# Processing Record 6 of Set 8 | kalmar
# Processing Record 7 of Set 8 | razole
# Processing Record 8 of Set 8 | kharagpur
# Processing Record 9 of Set 8 | cordoba
# Processing Record 10 of Set 8 | koulikoro
# Processing Record 11 of Set 8 | buritis
# Processing Record 12 of Set 8 | beloha
# Processing Record 13 of Set 8 | corrales
# Processing Record 14 of Set 8 | sokoni
# Processing Record 15 of Set 8 | izazi
# Processing Record 16 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 8 | srivardhan
# Processing Record 18 of Set 8 | salisbury
# Processing Record 19 of Set 8 | trelew
# Processing Record 20 of Set 8 | mogadishu
# Processing Record 21 of Set 8 | sangueya
# Processing Record 22 of Set 8 | shushtar
# Processing Record 23 of Set 8 | senneterre
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | natal
# Processing Record 26 of Set 8 | piacabucu
# Processing Record 27 of Set 8 | lugovoy
# Processing Record 28 of Set 8 | iberia
# Processing Record 29 of Set 8 | tuni
# Processing Record 30 of Set 8 | awjilah
# Processing Record 31 of Set 8 | tyulgan
# Processing Record 32 of Set 8 | pires do rio
# Processing Record 33 of Set 8 | priyutnoye
# Processing Record 34 of Set 8 | saint-pierre
# Processing Record 35 of Set 8 | nouakchott
# Processing Record 36 of Set 8 | hoyanger
# Processing Record 37 of Set 8 | estelle
# Processing Record 38 of Set 8 | pangnirtung
# Processing Record 39 of Set 8 | codrington
# Processing Record 40 of Set 8 | nioro
# Processing Record 41 of Set 8 | brinkovskaya
# Processing Record 42 of Set 8 | san carlos de bariloche
# Processing Record 43 of Set 8 | pisco
# Processing Record 44 of Set 8 | saint anthony
# Processing Record 45 of Set 8 | lahij
# Processing Record 46 of Set 8 | ugoofaaru
# Processing Record 47 of Set 8 | pachino
# Processing Record 48 of Set 8 | salcioara
# Processing Record 49 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 8 | panara
# Processing Record 1 of Set 9 | canavieiras
# Processing Record 2 of Set 9 | visby
# Processing Record 3 of Set 9 | zafra
# Processing Record 4 of Set 9 | filadelfia
# Processing Record 5 of Set 9 | siilinjarvi
# Processing Record 6 of Set 9 | namibe
# Processing Record 7 of Set 9 | bani
# Processing Record 8 of Set 9 | chibuto
# Processing Record 9 of Set 9 | anloga
# Processing Record 10 of Set 9 | gilgit
# Processing Record 11 of Set 9 | sur
# Processing Record 12 of Set 9 | frederico westphalen
# Processing Record 13 of Set 9 | amapa
# Processing Record 14 of Set 9 | linhares
# Processing Record 15 of Set 9 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 16 of Set 9 | konakovo
# Processing Record 17 of Set 9 | sirari
# Processing Record 18 of Set 9 | manitouwadge
# Processing Record 19 of Set 9 | san pedro de macoris
# Processing Record 20 of Set 9 | gujan-mestras
# Processing Record 21 of Set 9 | yarega
# Processing Record 22 of Set 9 | velsk
# Processing Record 23 of Set 9 | kavaratti
# Processing Record 24 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 9 | tazovskiy
# Processing Record 26 of Set 9 | bako
# Processing Record 27 of Set 9 | willowmore
# Processing Record 28 of Set 9 | tukrah
# Processing Record 29 of Set 9 | itaperucu
# Processing Record 30 of Set 9 | iquitos
# Processing Record 31 of Set 9 | stephenville crossing
# Processing Record 32 of Set 9 | dudinka
# Processing Record 33 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 35 of Set 9 | sokode
# Processing Record 36 of Set 9 | batie
# Processing Record 37 of Set 9 | rodrigues alves
# Processing Record 38 of Set 9 | mbarara
# Processing Record 39 of Set 9 | ocean city
# Processing Record 40 of Set 9 | bolobo
# Processing Record 41 of Set 9 | nieuw amsterdam
# Processing Record 42 of Set 9 | riyadh
# Processing Record 43 of Set 9 | nueve de julio
# Processing Record 44 of Set 9 | cruzeiro do sul
# Processing Record 45 of Set 9 | port blair
# Processing Record 46 of Set 9 | sorland
# Processing Record 47 of Set 9 | mahajanga
# Processing Record 48 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 9 | kalmunai
# Processing Record 50 of Set 9 | garissa
# Processing Record 1 of Set 10 | atakpame
# Processing Record 2 of Set 10 | alcaniz
# Processing Record 3 of Set 10 | sheopur
# Processing Record 4 of Set 10 | shenkursk
# Processing Record 5 of Set 10 | zhanaozen
# Processing Record 6 of Set 10 | sayyan
# Processing Record 7 of Set 10 | hebertville
# City not found. Skipping...
# Processing Record 8 of Set 10 | aleppo
# Processing Record 9 of Set 10 | abnub
# Processing Record 10 of Set 10 | manono
# Processing Record 11 of Set 10 | axim
# Processing Record 12 of Set 10 | dubai
# Processing Record 13 of Set 10 | abu samrah
# Processing Record 14 of Set 10 | yining
# Processing Record 15 of Set 10 | puerto ayacucho
# Processing Record 16 of Set 10 | iralaya
# Processing Record 17 of Set 10 | mehamn
# Processing Record 18 of Set 10 | jena
# Processing Record 19 of Set 10 | khailar
# Processing Record 20 of Set 10 | male
# Processing Record 21 of Set 10 | taoudenni
# Processing Record 22 of Set 10 | lodja
# Processing Record 23 of Set 10 | abonnema
# Processing Record 24 of Set 10 | manturovo
# Processing Record 25 of Set 10 | santa elena
# Processing Record 26 of Set 10 | gogrial
# Processing Record 27 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 28 of Set 10 | berlevag
# Processing Record 29 of Set 10 | sidi ali
# Processing Record 30 of Set 10 | zaria
# Processing Record 31 of Set 10 | madarounfa
# Processing Record 32 of Set 10 | juan lacaze
# Processing Record 33 of Set 10 | charlestown
# Processing Record 34 of Set 10 | iisalmi
# Processing Record 35 of Set 10 | kashary
# Processing Record 36 of Set 10 | milos
# Processing Record 37 of Set 10 | sisimiut
# Processing Record 38 of Set 10 | kamenka
# Processing Record 39 of Set 10 | faya
# Processing Record 40 of Set 10 | hambantota
# Processing Record 41 of Set 10 | sebrovo
# Processing Record 42 of Set 10 | laukaa
# Processing Record 43 of Set 10 | templin
# Processing Record 44 of Set 10 | man
# Processing Record 45 of Set 10 | abu dhabi
# Processing Record 46 of Set 10 | pemba
# Processing Record 47 of Set 10 | mercedes
# Processing Record 48 of Set 10 | chutove
# Processing Record 49 of Set 10 | skibbereen
# Processing Record 50 of Set 10 | bubaque
# Processing Record 1 of Set 11 | lajeado
# Processing Record 2 of Set 11 | urazovo
# Processing Record 3 of Set 11 | najran
# Processing Record 4 of Set 11 | konevo
# Processing Record 5 of Set 11 | horodok
# Processing Record 6 of Set 11 | taltal
# Processing Record 7 of Set 11 | padang
# Processing Record 8 of Set 11 | andra
# Processing Record 9 of Set 11 | qostanay
# Processing Record 10 of Set 11 | chimoio
# Processing Record 11 of Set 11 | bollnas
# Processing Record 12 of Set 11 | loding
# Processing Record 13 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 11 | kalemie
# Processing Record 15 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 16 of Set 11 | hryshkivtsi
# Processing Record 17 of Set 11 | san ignacio
# Processing Record 18 of Set 11 | okitipupa
# Processing Record 19 of Set 11 | bakchar
# Processing Record 20 of Set 11 | inongo
# Processing Record 21 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 11 | mozhga
# Processing Record 23 of Set 11 | negombo
# Processing Record 24 of Set 11 | puerto colombia
# Processing Record 25 of Set 11 | riberalta
# Processing Record 26 of Set 11 | oeiras do para
# Processing Record 27 of Set 11 | sterlibashevo
# Processing Record 28 of Set 11 | visnes
# Processing Record 29 of Set 11 | chake chake
# Processing Record 30 of Set 11 | trinidad
# Processing Record 31 of Set 11 | mantua
# Processing Record 32 of Set 11 | goedereede
# Processing Record 33 of Set 11 | birpur
# Processing Record 34 of Set 11 | shambu
# Processing Record 35 of Set 11 | fortaleza
# Processing Record 36 of Set 11 | lagos
# Processing Record 37 of Set 11 | mwense
# Processing Record 38 of Set 11 | camacupa
# Processing Record 39 of Set 11 | jaciara
# Processing Record 40 of Set 11 | ivanava
# Processing Record 41 of Set 11 | roald
# Processing Record 42 of Set 11 | hamilton
# Processing Record 43 of Set 11 | mecca
# Processing Record 44 of Set 11 | maragogi
# Processing Record 45 of Set 11 | kresttsy
# Processing Record 46 of Set 11 | mathbaria
# Processing Record 47 of Set 11 | pleshanovo
# Processing Record 48 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 49 of Set 11 | dustlik
# Processing Record 50 of Set 11 | sao gabriel
# Processing Record 1 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 2 of Set 12 | balkanabat
# Processing Record 3 of Set 12 | abrego
# Processing Record 4 of Set 12 | gat
# Processing Record 5 of Set 12 | lamu
# Processing Record 6 of Set 12 | koslan
# Processing Record 7 of Set 12 | grand-lahou
# Processing Record 8 of Set 12 | atar
# Processing Record 9 of Set 12 | tevriz
# Processing Record 10 of Set 12 | kemin
# Processing Record 11 of Set 12 | nuuk
# Processing Record 12 of Set 12 | komsomolskiy
# Processing Record 13 of Set 12 | doha
# Processing Record 14 of Set 12 | afsin
# Processing Record 15 of Set 12 | la asuncion
# Processing Record 16 of Set 12 | colesberg
# Processing Record 17 of Set 12 | mosquera
# Processing Record 18 of Set 12 | pimentel
# Processing Record 19 of Set 12 | saint marys
# Processing Record 20 of Set 12 | tornio
# Processing Record 21 of Set 12 | matagami
# Processing Record 22 of Set 12 | lincoln
# Processing Record 23 of Set 12 | sembe
# Processing Record 24 of Set 12 | nara
# Processing Record 25 of Set 12 | chazuta
# Processing Record 26 of Set 12 | miandrivazo
# Processing Record 27 of Set 12 | shache
# Processing Record 28 of Set 12 | madinat sittah uktubar
# Processing Record 29 of Set 12 | olinda
# Processing Record 30 of Set 12 | yuryevets
# Processing Record 31 of Set 12 | prieska
# Processing Record 32 of Set 12 | adra
# Processing Record 33 of Set 12 | savannah bight
# Processing Record 34 of Set 12 | fez
# Processing Record 35 of Set 12 | manhuacu
# Processing Record 36 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 37 of Set 12 | requena
# Processing Record 38 of Set 12 | sohbatpur
# Processing Record 39 of Set 12 | weymouth
# Processing Record 40 of Set 12 | tibati
# Processing Record 41 of Set 12 | nansio
# Processing Record 42 of Set 12 | khromtau
# Processing Record 43 of Set 12 | abakaliki
# Processing Record 44 of Set 12 | pedernales
# Processing Record 45 of Set 12 | vienna
# Processing Record 46 of Set 12 | palora
# Processing Record 47 of Set 12 | camocim
# Processing Record 48 of Set 12 | harsany
# Processing Record 49 of Set 12 | puerto carreno
# Processing Record 50 of Set 12 | huarmey
# Processing Record 1 of Set 13 | trapani
# Processing Record 2 of Set 13 | watsa
# Processing Record 3 of Set 13 | derzhavinsk
# Processing Record 4 of Set 13 | buarcos
# Processing Record 5 of Set 13 | saint-andre-avellin
# Processing Record 6 of Set 13 | oksfjord
# Processing Record 7 of Set 13 | weligama
# Processing Record 8 of Set 13 | chambery
# Processing Record 9 of Set 13 | portsmouth
# Processing Record 10 of Set 13 | thomaston
# Processing Record 11 of Set 13 | tutoia
# Processing Record 12 of Set 13 | grootfontein
# Processing Record 13 of Set 13 | san luis
# Processing Record 14 of Set 13 | baie-comeau
# Processing Record 15 of Set 13 | rocha
# Processing Record 16 of Set 13 | puri
# Processing Record 17 of Set 13 | ambilobe
# Processing Record 18 of Set 13 | watertown
# Processing Record 19 of Set 13 | carutapera
# Processing Record 20 of Set 13 | nalut
# Processing Record 21 of Set 13 | uniara
# Processing Record 22 of Set 13 | bethanien
# Processing Record 23 of Set 13 | pahalgam
# Processing Record 24 of Set 13 | maniitsoq
# Processing Record 25 of Set 13 | dubovskoye
# Processing Record 26 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 27 of Set 13 | patacamaya
# Processing Record 28 of Set 13 | kita
# Processing Record 29 of Set 13 | lypnyazhka
# Processing Record 30 of Set 13 | polunochnoye
# Processing Record 31 of Set 13 | znamenskoye
# Processing Record 32 of Set 13 | manyana
# Processing Record 33 of Set 13 | burica
# City not found. Skipping...
# Processing Record 34 of Set 13 | tabuk
# Processing Record 35 of Set 13 | sable-sur-sarthe
# Processing Record 36 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 13 | patan
# Processing Record 38 of Set 13 | opuwo
# Processing Record 39 of Set 13 | juigalpa
# Processing Record 40 of Set 13 | picota
# Processing Record 41 of Set 13 | honningsvag
# Processing Record 42 of Set 13 | camana
# Processing Record 43 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 13 | tamandare
# Processing Record 45 of Set 13 | banda aceh
# Processing Record 46 of Set 13 | hammerfest
# Processing Record 47 of Set 13 | havre-saint-pierre
# Processing Record 48 of Set 13 | torbat-e jam
# Processing Record 49 of Set 13 | ampanihy
# Processing Record 50 of Set 13 | beitbridge
# Processing Record 1 of Set 14 | lincoln village
# Processing Record 2 of Set 14 | mahibadhoo
# Processing Record 3 of Set 14 | carnot
# Processing Record 4 of Set 14 | wanlaweyn
# Processing Record 5 of Set 14 | santiago del estero
# Processing Record 6 of Set 14 | oriximina
# Processing Record 7 of Set 14 | orestias
# City not found. Skipping...
# Processing Record 8 of Set 14 | alexandria
# Processing Record 9 of Set 14 | dekar
# Processing Record 10 of Set 14 | shelburne
# Processing Record 11 of Set 14 | urumqi
# Processing Record 12 of Set 14 | karasjok
# Processing Record 13 of Set 14 | rockland
# Processing Record 14 of Set 14 | tambura
# Processing Record 15 of Set 14 | merritt island
# Processing Record 16 of Set 14 | wajir
# Processing Record 17 of Set 14 | ajdabiya
# Processing Record 18 of Set 14 | sao jose da coroa grande
# Processing Record 19 of Set 14 | homa bay
# Processing Record 20 of Set 14 | belogorsk
# Processing Record 21 of Set 14 | takob
# City not found. Skipping...
# Processing Record 22 of Set 14 | almiros
# City not found. Skipping...
# Processing Record 23 of Set 14 | elizabeth city
# Processing Record 24 of Set 14 | geraldton
# Processing Record 25 of Set 14 | imbituba
# Processing Record 26 of Set 14 | morant bay
# Processing Record 27 of Set 14 | sohag
# Processing Record 28 of Set 14 | naron
# Processing Record 29 of Set 14 | saint-paul
# Processing Record 30 of Set 14 | ostuni
# Processing Record 31 of Set 14 | bahia de caraquez
# Processing Record 32 of Set 14 | lalganj
# Processing Record 33 of Set 14 | werda
# Processing Record 34 of Set 14 | motril
# Processing Record 35 of Set 14 | port shepstone
# Processing Record 36 of Set 14 | constitucion
# Processing Record 37 of Set 14 | hofn
# Processing Record 38 of Set 14 | saint-raymond
# Processing Record 39 of Set 14 | panormos
# Processing Record 40 of Set 14 | el wasta
# City not found. Skipping...
# Processing Record 41 of Set 14 | louis trichardt
# Processing Record 42 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 14 | portage
# Processing Record 44 of Set 14 | englewood
# Processing Record 45 of Set 14 | edd
# Processing Record 46 of Set 14 | marica
# Processing Record 47 of Set 14 | shahrud
# Processing Record 48 of Set 14 | caraballeda
# Processing Record 49 of Set 14 | parana
# Processing Record 50 of Set 14 | semirom
# Processing Record 1 of Set 15 | halifax
# Processing Record 2 of Set 15 | lavumisa
# Processing Record 3 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 15 | elumalai
# Processing Record 5 of Set 15 | port hawkesbury
# Processing Record 6 of Set 15 | uyuni
# Processing Record 7 of Set 15 | barcelos
# Processing Record 8 of Set 15 | khatauli
# Processing Record 9 of Set 15 | terra santa
# Processing Record 10 of Set 15 | oranjestad
# Processing Record 11 of Set 15 | kamra
# Processing Record 12 of Set 15 | rundu
# Processing Record 13 of Set 15 | san-pedro
# Processing Record 14 of Set 15 | lisala
# Processing Record 15 of Set 15 | pangoa
# Processing Record 16 of Set 15 | angoche
# Processing Record 17 of Set 15 | santo antonio do ica
# Processing Record 18 of Set 15 | cutlerville
# Processing Record 19 of Set 15 | tocopilla
# Processing Record 20 of Set 15 | kang
# Processing Record 21 of Set 15 | maimon
# City not found. Skipping...
# Processing Record 22 of Set 15 | orocue
# Processing Record 23 of Set 15 | iki-burul
# Processing Record 24 of Set 15 | beisfjord
# Processing Record 25 of Set 15 | port-de-paix
# City not found. Skipping...
# Processing Record 26 of Set 15 | lalibela
# Processing Record 27 of Set 15 | melnikovo
# Processing Record 28 of Set 15 | oreanda
# City not found. Skipping...
# Processing Record 29 of Set 15 | sanghar
# Processing Record 30 of Set 15 | troitskoye
# Processing Record 31 of Set 15 | liverpool
# Processing Record 32 of Set 15 | the valley
# Processing Record 33 of Set 15 | toktogul
# Processing Record 34 of Set 15 | abengourou
# Processing Record 35 of Set 15 | la gaulette
# City not found. Skipping...
# Processing Record 36 of Set 15 | sao joaquim
# Processing Record 37 of Set 15 | kattivakkam
# Processing Record 38 of Set 15 | tiruvallur
# Processing Record 39 of Set 15 | lourdes
# Processing Record 40 of Set 15 | ayagoz
# Processing Record 41 of Set 15 | valenca
# Processing Record 42 of Set 15 | campoverde
# Processing Record 43 of Set 15 | leh
# Processing Record 44 of Set 15 | parry sound
# Processing Record 45 of Set 15 | ler
# Processing Record 46 of Set 15 | ostersund
# Processing Record 47 of Set 15 | nicoya
# Processing Record 48 of Set 15 | plettenberg bay
# Processing Record 49 of Set 15 | bella union
# Processing Record 50 of Set 15 | guarapari
# Processing Record 1 of Set 16 | curitibanos
# Processing Record 2 of Set 16 | teberda
# Processing Record 3 of Set 16 | cajaruro
# Processing Record 4 of Set 16 | verkhnyaya inta
# Processing Record 5 of Set 16 | la roche-sur-yon
# Processing Record 6 of Set 16 | sika
# Processing Record 7 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 16 | gilbues
# Processing Record 9 of Set 16 | olden
# Processing Record 10 of Set 16 | uruacu
# Processing Record 11 of Set 16 | mbini
# Processing Record 12 of Set 16 | kumbo
# Processing Record 13 of Set 16 | yadgir
# Processing Record 14 of Set 16 | san juan de arama
# Processing Record 15 of Set 16 | north myrtle beach
# Processing Record 16 of Set 16 | moose factory
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
#len(city_data)
print(len(city_data))
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       La Romana  18.4273 -68.9728     84.56        70          20
# 1          Lodwar   3.1191  35.5973     88.84        33          56
# 2       Cape Town -33.9258  18.4232     70.38        81          20
# 3  Ribeira Grande  38.5167 -28.7000     63.00        82          75
# 4     East London -33.0153  27.9116     72.46        69           0
# 5         Ushuaia -54.8000 -68.3000     53.26        43          40
# 6         Sakakah  29.9697  40.2064     65.77        35           0
# 7    Ponta Do Sol  32.6667 -17.1000     70.00        91          68
# 8    Richards Bay -28.7830  32.0377     75.13        79           0
# 9         Qaanaaq  77.4840 -69.3632      5.18        76           0
#
#    Wind Speed       Description
# 0        6.91        few clouds
# 1        7.20     broken clouds
# 2       11.50        few clouds
# 3       19.57     broken clouds
# 4        8.95         clear sky
# 5       11.50  scattered clouds
# 6       14.85         clear sky
# 7        6.51     broken clouds
# 8       11.88         clear sky
# 9        8.30         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       La Romana  18.4273 -68.9728     84.56        70          20
# 1          Lodwar   3.1191  35.5973     88.84        33          56
# 2       Cape Town -33.9258  18.4232     70.38        81          20
# 3  Ribeira Grande  38.5167 -28.7000     63.00        82          75
# 4     East London -33.0153  27.9116     72.46        69           0
# 5         Ushuaia -54.8000 -68.3000     53.26        43          40
# 6         Sakakah  29.9697  40.2064     65.77        35           0
# 7    Ponta Do Sol  32.6667 -17.1000     70.00        91          68
# 8    Richards Bay -28.7830  32.0377     75.13        79           0
# 9         Qaanaaq  77.4840 -69.3632      5.18        76           0
#
#    Wind Speed       Description
# 0        6.91        few clouds
# 1        7.20     broken clouds
# 2       11.50        few clouds
# 3       19.57     broken clouds
# 4        8.95         clear sky
# 5       11.50  scattered clouds
# 6       14.85         clear sky
# 7        6.51     broken clouds
# 8       11.88         clear sky
# 9        8.30         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
